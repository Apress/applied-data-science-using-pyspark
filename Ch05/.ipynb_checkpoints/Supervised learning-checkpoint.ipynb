# %% [markdown]
# # Default Parameters

# %%
filename = "bank-full.csv"
target_variable_name = "y"

# %% [markdown]
# # Load Dataset

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
data = spark.read.csv(filename, header=True, inferSchema=True, sep=';')
data.show()
# Out:
# +---+------------+--------+---------+-------+-------+-------+----+-------+---+-----+--------+--------+-----+--------+--------+---+
# |age|         job| marital|education|default|balance|housing|loan|contact|day|month|duration|campaign|pdays|previous|poutcome|  y|
# +---+------------+--------+---------+-------+-------+-------+----+-------+---+-----+--------+--------+-----+--------+--------+---+
# | 58|  management| married| tertiary|     no|   2143|    yes|  no|unknown|  5|  may|     261|       1|   -1|       0| unknown| no|
# | 44|  technician|  single|secondary|     no|     29|    yes|  no|unknown|  5|  may|     151|       1|   -1|       0| unknown| no|
# | 33|entrepreneur| married|secondary|     no|      2|    yes| yes|unknown|  5|  may|      76|       1|   -1|       0| unknown| no|
# | 47| blue-collar| married|  unknown|     no|   1506|    yes|  no|unknown|  5|  may|      92|       1|   -1|       0| unknown| no|
# | 33|     unknown|  single|  unknown|     no|      1|     no|  no|unknown|  5|  may|     198|       1|   -1|       0| unknown| no|
# | 35|  management| married| tertiary|     no|    231|    yes|  no|unknown|  5|  may|     139|       1|   -1|       0| unknown| no|
# | 28|  management|  single| tertiary|     no|    447|    yes| yes|unknown|  5|  may|     217|       1|   -1|       0| unknown| no|
# | 42|entrepreneur|divorced| tertiary|    yes|      2|    yes|  no|unknown|  5|  may|     380|       1|   -1|       0| unknown| no|
# | 58|     retired| married|  primary|     no|    121|    yes|  no|unknown|  5|  may|      50|       1|   -1|       0| unknown| no|
# | 43|  technician|  single|secondary|     no|    593|    yes|  no|unknown|  5|  may|      55|       1|   -1|       0| unknown| no|
# | 41|      admin.|divorced|secondary|     no|    270|    yes|  no|unknown|  5|  may|     222|       1|   -1|       0| unknown| no|
# | 29|      admin.|  single|secondary|     no|    390|    yes|  no|unknown|  5|  may|     137|       1|   -1|       0| unknown| no|
# | 53|  technician| married|secondary|     no|      6|    yes|  no|unknown|  5|  may|     517|       1|   -1|       0| unknown| no|
# | 58|  technician| married|  unknown|     no|     71|    yes|  no|unknown|  5|  may|      71|       1|   -1|       0| unknown| no|
# | 57|    services| married|secondary|     no|    162|    yes|  no|unknown|  5|  may|     174|       1|   -1|       0| unknown| no|
# | 51|     retired| married|  primary|     no|    229|    yes|  no|unknown|  5|  may|     353|       1|   -1|       0| unknown| no|
# | 45|      admin.|  single|  unknown|     no|     13|    yes|  no|unknown|  5|  may|      98|       1|   -1|       0| unknown| no|
# | 57| blue-collar| married|  primary|     no|     52|    yes|  no|unknown|  5|  may|      38|       1|   -1|       0| unknown| no|
# | 60|     retired| married|  primary|     no|     60|    yes|  no|unknown|  5|  may|     219|       1|   -1|       0| unknown| no|
# | 33|    services| married|secondary|     no|      0|    yes|  no|unknown|  5|  may|      54|       1|   -1|       0| unknown| no|
# +---+------------+--------+---------+-------+-------+-------+----+-------+---+-----+--------+--------+-----+--------+--------+---+
# only showing top 20 rows

# %% [markdown]
# # Length of the data

# %%
data.count()
# Out:
# 45211

# %% [markdown]
# # Describe data

# %%
data.describe().toPandas()
# Out:
#   summary                 age      job   marital education default  \
# 0   count               45211    45211     45211     45211   45211
# 1    mean   40.93621021432837     None      None      None    None
# 2  stddev  10.618762040975401     None      None      None    None
# 3     min                  18   admin.  divorced   primary      no
# 4     max                  95  unknown    single   unknown     yes
#
#               balance housing   loan   contact                day  month  \
# 0               45211   45211  45211     45211              45211  45211
# 1  1362.2720576850766    None   None      None  15.80641879188693   None
# 2  3044.7658291685243    None   None      None  8.322476153044589   None
# 3               -8019      no     no  cellular                  1    apr
# 4              102127     yes    yes   unknown                 31    sep
#
#             duration            campaign               pdays  \
# 0              45211               45211               45211
# 1  258.1630797814691   2.763840658246887   40.19782796222158
# 2  257.5278122651712  3.0980208832791813  100.12874599059818
# 3                  0                   1                  -1
# 4               4918                  63                 871
#
#              previous poutcome      y
# 0               45211    45211  45211
# 1  0.5803233726305546     None   None
# 2  2.3034410449312164     None   None
# 3                   0  failure     no
# 4                 275  unknown    yes

# %% [markdown]
# # Check Data types of each column

# %%
data.groupby('marital').count().show()
# Out:
# +-------+-----+
# |marital|count|
# +-------+-----+
# |    0.0|27214|
# |    1.0|12790|
# |    2.0| 5207|
# +-------+-----+

# %%
data.dtypes
# Out:
# [('age', 'int'),
#  ('job', 'string'),
#  ('marital', 'string'),
#  ('education', 'string'),
#  ('default', 'string'),
#  ('balance', 'int'),
#  ('housing', 'string'),
#  ('loan', 'string'),
#  ('contact', 'string'),
#  ('day', 'int'),
#  ('month', 'string'),
#  ('duration', 'int'),
#  ('campaign', 'int'),
#  ('pdays', 'int'),
#  ('previous', 'int'),
#  ('poutcome', 'string'),
#  ('y', 'string')]

# %%
data.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- default: string (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- y: string (nullable = true)

# %%
from pyspark.sql.functions import * 
data.groupBy(target_variable_name).agg({'balance':'avg', 'age': 'avg'}).show()
# Out:
# +---+------------------+------------------+
# |  y|      avg(balance)|          avg(age)|
# +---+------------------+------------------+
# | no|1303.7149691899203| 40.83898602274435|
# |yes|1804.2679145396105|41.670069956513515|
# +---+------------------+------------------+

# %% [markdown]
# # Cardinality Check

# %%
from pyspark.sql.functions import approxCountDistinct, countDistinct

"""
Note: approxCountDistinct and countDistinct can be used interchangeably. Only difference is the computation time. 

"approxCountDistinct" is useful for large datasets 
"countDistinct" for small and medium datasets.

"""

def cardinality_calculation(df, cut_off=1):
    cardinality = df.select(*[approxCountDistinct(c).alias(c) for c in df.columns])
    
    ## convert to pandas for efficient calculations
    final_cardinality_df = cardinality.toPandas().transpose()
    final_cardinality_df.reset_index(inplace=True) 
    final_cardinality_df.rename(columns={0:'Cardinality'}, inplace=True) 
    
    #select variables with cardinality of 1
    vars_selected = final_cardinality_df['index'][final_cardinality_df['Cardinality'] <= cut_off] 
    
    return final_cardinality_df, vars_selected

cardinality_df, cardinality_vars_selected = cardinality_calculation(data)

# %%
cardinality_df
# Out:
#         index  Cardinality
# 0         age           76
# 1         job           11
# 2     marital            3
# 3   education            4
# 4     default            2
# 5     balance         7375
# 6     housing            2
# 7        loan            2
# 8     contact            3
# 9         day           32
# 10      month           12
# 11   duration         1605
# 12   campaign           47
# 13      pdays          547
# 14   previous           42
# 15   poutcome            4
# 16          y            2

# %%
cardinality_vars_selected
# Out:
# Series([], Name: index, dtype: object)

# %% [markdown]
# # Missing value check

# %%
#missing values check
from pyspark.sql.functions import count, when, isnan, col

# miss_percentage is set to 80% as discussed in the book
def missing_calculation(df, miss_percentage=0.80):
    
    #checks for both NaN and null values
    missing = df.select(*[count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df.columns])
    length_df = df.count()
    ## convert to pandas for efficient calculations
    final_missing_df = missing.toPandas().transpose()
    final_missing_df.reset_index(inplace=True) 
    final_missing_df.rename(columns={0:'missing_count'}, inplace=True) 
    final_missing_df['missing_percentage'] = final_missing_df['missing_count']/length_df
    
    #select variables with cardinality of 1
    vars_selected = final_missing_df['index'][final_missing_df['missing_percentage'] >= miss_percentage] 
    
    return final_missing_df, vars_selected

# %%
missing_df, missing_vars_selected = missing_calculation(data)

# %%
missing_df
# Out:
#         index  missing_count  missing_percentage
# 0         age              0                 0.0
# 1         job              0                 0.0
# 2     marital              0                 0.0
# 3   education              0                 0.0
# 4     default              0                 0.0
# 5     balance              0                 0.0
# 6     housing              0                 0.0
# 7        loan              0                 0.0
# 8     contact              0                 0.0
# 9         day              0                 0.0
# 10      month              0                 0.0
# 11   duration              0                 0.0
# 12   campaign              0                 0.0
# 13      pdays              0                 0.0
# 14   previous              0                 0.0
# 15   poutcome              0                 0.0
# 16          y              0                 0.0

# %%
missing_vars_selected
# Out:
# Series([], Name: index, dtype: object)

# %% [markdown]
# # Identify variable types

# %%
def variable_type(df):
    
    vars_list = df.dtypes
    char_vars = []
    num_vars = []
    for i in vars_list:
        if i[1] in ('string'):
            char_vars.append(i[0])
        else:
            num_vars.append(i[0])
    
    return char_vars, num_vars

# %%
char_vars, num_vars = variable_type(data)

# %%
char_vars
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'y']

# %%
num_vars
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline

def category_to_index(df, char_vars):
    
    char_df = df.select(char_vars)
    indexers = [StringIndexer(inputCol=c, outputCol=c+"_index", handleInvalid="keep") for c in char_df.columns]
    pipeline = Pipeline(stages=indexers)
    char_labels = pipeline.fit(char_df)
    df = char_labels.transform(df)
    return df, char_labels

# %%
data, char_labels = category_to_index(data, char_vars)

# %%
data.dtypes
# Out:
# [('age', 'int'),
#  ('job', 'string'),
#  ('marital', 'string'),
#  ('education', 'string'),
#  ('default', 'string'),
#  ('balance', 'int'),
#  ('housing', 'string'),
#  ('loan', 'string'),
#  ('contact', 'string'),
#  ('day', 'int'),
#  ('month', 'string'),
#  ('duration', 'int'),
#  ('campaign', 'int'),
#  ('pdays', 'int'),
#  ('previous', 'int'),
#  ('poutcome', 'string'),
#  ('y', 'string'),
#  ('job_index', 'double'),
#  ('marital_index', 'double'),
#  ('education_index', 'double'),
#  ('default_index', 'double'),
#  ('housing_index', 'double'),
#  ('loan_index', 'double'),
#  ('contact_index', 'double'),
#  ('month_index', 'double'),
#  ('poutcome_index', 'double'),
#  ('y_index', 'double')]

# %%
data = data.select([c for c in data.columns if c not in char_vars])

# %%
def rename_columns(df, char_vars):
    mapping = dict(zip([i + '_index' for i in char_vars], char_vars))
    df = df.select([col(c).alias(mapping.get(c, c)) for c in df.columns])
    return df

# %%
data = rename_columns(data, char_vars)

# %%
data.dtypes
# Out:
# [('age', 'int'),
#  ('balance', 'int'),
#  ('day', 'int'),
#  ('duration', 'int'),
#  ('campaign', 'int'),
#  ('pdays', 'int'),
#  ('previous', 'int'),
#  ('job', 'double'),
#  ('marital', 'double'),
#  ('education', 'double'),
#  ('default', 'double'),
#  ('housing', 'double'),
#  ('loan', 'double'),
#  ('contact', 'double'),
#  ('month', 'double'),
#  ('poutcome', 'double'),
#  ('y', 'double')]

# %%
data.groupBy('y').count().show()
# Out:
# +---+-----+
# |  y|count|
# +---+-----+
# |0.0|39922|
# |1.0| 5289|
# +---+-----+

# %%
linear_df = data.select(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'])

# %%
linear_df
# Out:
# DataFrame[age: int, balance: int, day: int, duration: int, campaign: int, pdays: int, previous: int]

# %%
target_variable_name = 'balance'

# %% [markdown]
# # Assemble input vectors

# %%
from pyspark.ml.feature import VectorAssembler

#assemble individual columns to one column - 'features'
def assemble_vectors(df, features_list, target_variable_name):
    stages = []
    #assemble vectors
    assembler = VectorAssembler(inputCols=features_list, outputCol='features')
    stages = [assembler]
    #select all the columns + target + newly created 'features' column
    selectedCols = [target_variable_name, 'features'] + features_list
    #use pipeline to process sequentially
    pipeline = Pipeline(stages=stages)
    #assembler model
    assembleModel = pipeline.fit(df)
    #apply assembler model on data
    df = assembleModel.transform(df).select(selectedCols)

    return df

# %%
#exclude target variable and select all other feature vectors
features_list = linear_df.columns
#features_list = char_vars #this option is used only for ChiSqselector
features_list.remove(target_variable_name)

# %%
features_list
# Out:
# ['age', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
# apply the function on our dataframe
df = assemble_vectors(linear_df, features_list, target_variable_name)

# %%
df.show()
# Out:
# +-------+--------------------+---+---+--------+--------+-----+--------+
# |balance|            features|age|day|duration|campaign|pdays|previous|
# +-------+--------------------+---+---+--------+--------+-----+--------+
# |   2143|[58.0,5.0,261.0,1...| 58|  5|     261|       1|   -1|       0|
# |     29|[44.0,5.0,151.0,1...| 44|  5|     151|       1|   -1|       0|
# |      2|[33.0,5.0,76.0,1....| 33|  5|      76|       1|   -1|       0|
# |   1506|[47.0,5.0,92.0,1....| 47|  5|      92|       1|   -1|       0|
# |      1|[33.0,5.0,198.0,1...| 33|  5|     198|       1|   -1|       0|
# |    231|[35.0,5.0,139.0,1...| 35|  5|     139|       1|   -1|       0|
# |    447|[28.0,5.0,217.0,1...| 28|  5|     217|       1|   -1|       0|
# |      2|[42.0,5.0,380.0,1...| 42|  5|     380|       1|   -1|       0|
# |    121|[58.0,5.0,50.0,1....| 58|  5|      50|       1|   -1|       0|
# |    593|[43.0,5.0,55.0,1....| 43|  5|      55|       1|   -1|       0|
# |    270|[41.0,5.0,222.0,1...| 41|  5|     222|       1|   -1|       0|
# |    390|[29.0,5.0,137.0,1...| 29|  5|     137|       1|   -1|       0|
# |      6|[53.0,5.0,517.0,1...| 53|  5|     517|       1|   -1|       0|
# |     71|[58.0,5.0,71.0,1....| 58|  5|      71|       1|   -1|       0|
# |    162|[57.0,5.0,174.0,1...| 57|  5|     174|       1|   -1|       0|
# |    229|[51.0,5.0,353.0,1...| 51|  5|     353|       1|   -1|       0|
# |     13|[45.0,5.0,98.0,1....| 45|  5|      98|       1|   -1|       0|
# |     52|[57.0,5.0,38.0,1....| 57|  5|      38|       1|   -1|       0|
# |     60|[60.0,5.0,219.0,1...| 60|  5|     219|       1|   -1|       0|
# |      0|[33.0,5.0,54.0,1....| 33|  5|      54|       1|   -1|       0|
# +-------+--------------------+---+---+--------+--------+-----+--------+
# only showing top 20 rows

# %% [markdown]
# # Linear Regression

# %%
from pyspark.ml.regression import LinearRegression
reg = LinearRegression(featuresCol='features', labelCol='balance')
reg_model = reg.fit(df) # fit model

# %%
import pandas as pd
for k, v in df.schema["features"].metadata["ml_attr"]["attrs"].items():
    features_df = pd.DataFrame(v)

# print coefficient and intercept
print(reg_model.coefficients, reg_model.intercept)

features_df['coefficients'] = reg_model.coefficients
# Out:
# [28.08397290892997,3.3055463619496286,0.24882841970901756,-14.142676297161454,-0.08248810233032043,23.462992800762525] 124.92130092818479

# %%
features_df
# Out:
#    idx      name  coefficients
# 0    0       age     28.083973
# 1    1       day      3.305546
# 2    2  duration      0.248828
# 3    3  campaign    -14.142676
# 4    4     pdays     -0.082488
# 5    5  previous     23.462993

# %%
#prediction result
pred_result = reg_model.transform(df)

# %%
pred_result
# Out:
# DataFrame[balance: int, features: vector, age: int, day: int, duration: int, campaign: int, pdays: int, previous: int, prediction: double]

# %%
reg_model.summary.r2
# Out:
# 0.01056811651155165

# %%
features_list
# Out:
# ['age', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %% [markdown]
# # Variance Inflation factor

# %%
def vif_calculator(df, features_list):
    vif_list = []
    for i in features_list:
        temp_features_list = features_list.copy()
        temp_features_list.remove(i)
        temp_target = i
        assembler = VectorAssembler(inputCols=temp_features_list, outputCol='features')
        temp_df = assembler.transform(df)
        reg = LinearRegression(featuresCol='features', labelCol=i)
        reg_model = reg.fit(temp_df) # fit model
        temp_vif = 1/(1 - reg_model.summary.r2)
        vif_list.append(temp_vif)
    return vif_list

# %%
features_df['vif'] = vif_calculator(linear_df, features_list)

# %%
features_df
# Out:
#    idx      name  coefficients       vif
# 0    0       age     28.083973  1.000917
# 1    1       day      3.305546  1.034350
# 2    2  duration      0.248828  1.007627
# 3    3  campaign    -14.142676  1.039907
# 4    4     pdays     -0.082488  1.276182
# 5    5  previous     23.462993  1.261321

# %% [markdown]
# # Logistic Regression

# %%
target_variable_name = "y"
logistic_df = data.select(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous', 'y'])
#exclude target variable and select all other feature vectors
features_list = logistic_df.columns
#features_list = char_vars #this option is used only for ChiSqselector
features_list.remove(target_variable_name)
# apply the function on our dataframe
df = assemble_vectors(logistic_df, features_list, target_variable_name)

# %%
from pyspark.ml.classification import LogisticRegression
binary_clf = LogisticRegression(featuresCol='features', labelCol='y', family='binomial')
multinomial_clf = LogisticRegression(featuresCol='features', labelCol='y', family='multinomial')
binary_clf_model = binary_clf.fit(df) # fit binary model
multinomial_clf_model = multinomial_clf.fit(df) # fit multinomial model

# %%
import numpy as np
np.set_printoptions(precision=3, suppress=True)
binary_clf_model.coefficients
# Out:
# DenseVector([0.008, 0.0, -0.0017, 0.0036, -0.128, 0.0021, 0.0859])

# %%
np.set_printoptions(precision=4, suppress=True)
print(multinomial_clf_model.coefficientMatrix)
# Out:
# DenseMatrix([[-0.004 , -0.    ,  0.0008, -0.0018,  0.064 , -0.0011, -0.043 ],
#              [ 0.004 ,  0.    , -0.0008,  0.0018, -0.064 ,  0.0011,  0.043 ]])

# %%
binary_clf_model.intercept
# Out:
# -3.4699010654247706

# %%
print(multinomial_clf_model.interceptVector)
# Out:
# [1.7349520795817952,-1.7349520795817952]

# %% [markdown]
# # Decision Trees

# %%
target_variable_name = "y"
logistic_df = data.select(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous', 'y'])
#exclude target variable and select all other feature vectors
features_list = logistic_df.columns
#features_list = char_vars #this option is used only for ChiSqselector
features_list.remove(target_variable_name)
# apply the function on our dataframe
binary_df = assemble_vectors(logistic_df, features_list, target_variable_name)

# %%
target_variable_name = "balance"
linear_df = data.select(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'])
#exclude target variable and select all other feature vectors
features_list = linear_df.columns
#features_list = char_vars #this option is used only for ChiSqselector
features_list.remove(target_variable_name)
# apply the function on our dataframe
continuous_df = assemble_vectors(linear_df, features_list, target_variable_name)

# %%
from pyspark.ml.classification import DecisionTreeClassifier

clf = DecisionTreeClassifier(featuresCol='features', labelCol='y', impurity='gini')
clf_model = clf.fit(binary_df)
clf2 = DecisionTreeClassifier(featuresCol='features', labelCol='y', impurity='entropy')
clf_model2 = clf2.fit(binary_df)

# %%
print(clf_model.featureImportances)
# Out:
# (7,[0,2,3,4,5],[0.061080523824779846,0.001401144004739516,0.725563927693075,0.0006452473752840746,0.2113091571021216])

# %%
print(clf_model2.featureImportances)
# Out:
# (7,[0,2,3,4,5],[0.016525034911207683,0.0008843867764161639,0.7259910167111736,0.00047544455167873026,0.25612411704952387])

# %%
from pyspark.ml.regression import DecisionTreeRegressor

reg = DecisionTreeRegressor(featuresCol='features', labelCol='balance', impurity='variance')
reg_model = reg.fit(continuous_df)

# %%
clf_model.toDebugString
# Out:
# 'DecisionTreeClassificationModel (uid=DecisionTreeClassifier_c36bddc53faa) of depth 5 with 37 nodes\n  If (feature 3 <= 489.5)\n   If (feature 5 <= 9.5)\n    If (feature 0 <= 60.5)\n     Predict: 0.0\n    Else (feature 0 > 60.5)\n     If (feature 3 <= 129.5)\n      Predict: 0.0\n     Else (feature 3 > 129.5)\n      If (feature 3 <= 206.5)\n       Predict: 0.0\n      Else (feature 3 > 206.5)\n       Predict: 1.0\n   Else (feature 5 > 9.5)\n    If (feature 3 <= 180.5)\n     Predict: 0.0\n    Else (feature 3 > 180.5)\n     If (feature 5 <= 190.5)\n      If (feature 5 <= 96.5)\n       Predict: 1.0\n      Else (feature 5 > 96.5)\n       Predict: 0.0\n     Else (feature 5 > 190.5)\n      Predict: 0.0\n  Else (feature 3 > 489.5)\n   If (feature 3 <= 691.0)\n    If (feature 5 <= 8.5)\n     If (feature 3 <= 576.5)\n      If (feature 0 <= 60.5)\n       Predict: 0.0\n      Else (feature 0 > 60.5)\n       Predict: 1.0\n     Else (feature 3 > 576.5)\n      Predict: 0.0\n    Else (feature 5 > 8.5)\n     If (feature 5 <= 96.5)\n      Predict: 1.0\n     Else (feature 5 > 96.5)\n      If (feature 0 <= 58.5)\n       Predict: 0.0\n      Else (feature 0 > 58.5)\n       Predict: 1.0\n   Else (feature 3 > 691.0)\n    If (feature 3 <= 917.5)\n     If (feature 5 <= 27.5)\n      Predict: 0.0\n     Else (feature 5 > 27.5)\n      Predict: 1.0\n    Else (feature 3 > 917.5)\n     If (feature 2 <= 29.5)\n      If (feature 4 <= 24.5)\n       Predict: 1.0\n      Else (feature 4 > 24.5)\n       Predict: 0.0\n     Else (feature 2 > 29.5)\n      Predict: 1.0\n'

# %% [markdown]
# ## String to Json parser

# %%
def parse(lines):
    block = []
    while lines :

        if lines[0].startswith('If'):
            bl = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
            block.append({'id':bl, 'children':parse(lines)})


            if lines[0].startswith('Else'):
                be = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
                block.append({'id':be, 'children':parse(lines)})
        elif not lines[0].startswith(('If','Else')):
            block2 = lines.pop(0)
            block.append({'id':block2})
        else:
            break
    return block

def tree_json(tree):
    data = []
    for line in tree.splitlines() : 
        if line.strip():
            line = line.strip()
            data.append(line)
        else : break
        if not line : break
    res = []
    res.append({'id':'Root', 'children':parse(data[1:])})
    return res[0]

# %%
result = tree_json(clf_model.toDebugString)

# %%
from pyspark.sql.types import IntegerType
from pyspark.sql.types import StructField, StructType

cSchema = StructType([StructField("age", IntegerType())\
                      ,StructField("gender", IntegerType())\
                      ,StructField("y", IntegerType())])

test_list = [[30, 0, 1], 
             [25, 1, 0], 
             [45, 0, 0], 
             [57, 1, 1],
             [27, 0, 1], 
             [54, 1, 1], 
             [35, 1, 1]]


test_df = spark.createDataFrame(test_list, schema=cSchema)
test_df.show()
# Out:
# +---+------+---+
# |age|gender|  y|
# +---+------+---+
# | 30|     0|  1|
# | 25|     1|  0|
# | 45|     0|  0|
# | 57|     1|  1|
# | 27|     0|  1|
# | 54|     1|  1|
# | 35|     1|  1|
# +---+------+---+

# %%
test_df = assemble_vectors(test_df, ['age','gender'], 'y')
test_clf = DecisionTreeClassifier(featuresCol='features', labelCol='y')
test_clf_model = test_clf.fit(test_df)

# %%
clf_model.featureImportances
# Out:
# SparseVector(7, {0: 0.0611, 2: 0.0014, 3: 0.7256, 4: 0.0006, 5: 0.2113})

# %%
test_clf_model.toDebugString
# Out:
# 'DecisionTreeClassificationModel (uid=DecisionTreeClassifier_2800c35732d6) of depth 3 with 7 nodes\n  If (feature 0 <= 26.0)\n   Predict: 0.0\n  Else (feature 0 > 26.0)\n   If (feature 0 <= 40.0)\n    Predict: 1.0\n   Else (feature 0 > 40.0)\n    If (feature 0 <= 49.5)\n     Predict: 0.0\n    Else (feature 0 > 49.5)\n     Predict: 1.0\n'

# %% [markdown]
# # Random Forest

# %%
from pyspark.ml.classification import RandomForestClassifier

clf = RandomForestClassifier(featuresCol='features', labelCol='y')
clf_model = clf.fit(binary_df)
print(clf_model.featureImportances)
print(clf_model.toDebugString)
# Out:
# (7,[0,1,2,3,4,5,6],[0.04089763741220326,0.00998065797800152,0.034217284862762806,0.6641622198323902,0.00418593339969165,0.19243787980500565,0.054118386709944885])
# RandomForestClassificationModel (uid=RandomForestClassifier_8049ea3f17d3) with 20 trees
#   Tree 0 (weight 1.0):
#     If (feature 3 <= 490.5)
#      If (feature 6 <= 0.5)
#       Predict: 0.0
#      Else (feature 6 > 0.5)
#       If (feature 5 <= 188.5)
#        If (feature 3 <= 168.5)
#         Predict: 0.0
#        Else (feature 3 > 168.5)
#         If (feature 0 <= 30.5)
#          Predict: 1.0
#         Else (feature 0 > 30.5)
#          Predict: 0.0
#       Else (feature 5 > 188.5)
#        Predict: 0.0
#     Else (feature 3 > 490.5)
#      If (feature 5 <= 28.0)
#       If (feature 0 <= 32.5)
#        If (feature 3 <= 913.0)
#         Predict: 0.0
#        Else (feature 3 > 913.0)
#         If (feature 2 <= 2.5)
#          Predict: 0.0
#         Else (feature 2 > 2.5)
#          Predict: 1.0
#       Else (feature 0 > 32.5)
#        If (feature 0 <= 59.5)
#         Predict: 0.0
#        Else (feature 0 > 59.5)
#         Predict: 1.0
#      Else (feature 5 > 28.0)
#       If (feature 5 <= 95.5)
#        If (feature 6 <= 5.5)
#         If (feature 2 <= 1.5)
#          Predict: 0.0
#         Else (feature 2 > 1.5)
#          Predict: 1.0
#        Else (feature 6 > 5.5)
#         If (feature 0 <= 57.5)
#          Predict: 1.0
#         Else (feature 0 > 57.5)
#          Predict: 0.0
#       Else (feature 5 > 95.5)
#        If (feature 1 <= 3804.0)
#         If (feature 0 <= 59.5)
#          Predict: 0.0
#         Else (feature 0 > 59.5)
#          Predict: 1.0
#        Else (feature 1 > 3804.0)
#         Predict: 1.0
#   Tree 1 (weight 1.0):
#     If (feature 3 <= 490.5)
#      If (feature 5 <= 9.5)
#       Predict: 0.0
#      Else (feature 5 > 9.5)
#       If (feature 3 <= 149.5)
#        Predict: 0.0
#       Else (feature 3 > 149.5)
#        If (feature 2 <= 21.5)
#         Predict: 0.0
#        Else (feature 2 > 21.5)
#         If (feature 5 <= 188.5)
#          Predict: 1.0
#         Else (feature 5 > 188.5)
#          Predict: 0.0
#     Else (feature 3 > 490.5)
#      If (feature 6 <= 0.5)
#       If (feature 3 <= 695.5)
#        Predict: 0.0
#       Else (feature 3 > 695.5)
#        If (feature 0 <= 30.5)
#         Predict: 1.0
#        Else (feature 0 > 30.5)
#         If (feature 1 <= 9.5)
#          Predict: 0.0
#         Else (feature 1 > 9.5)
#          Predict: 1.0
#      Else (feature 6 > 0.5)
#       If (feature 2 <= 21.5)
#        If (feature 2 <= 15.5)
#         Predict: 1.0
#        Else (feature 2 > 15.5)
#         If (feature 1 <= 5044.0)
#          Predict: 0.0
#         Else (feature 1 > 5044.0)
#          Predict: 1.0
#       Else (feature 2 > 21.5)
#        If (feature 6 <= 12.5)
#         If (feature 5 <= 3.0)
#          Predict: 0.0
#         Else (feature 5 > 3.0)
#          Predict: 1.0
#        Else (feature 6 > 12.5)
#         Predict: 0.0
#   Tree 2 (weight 1.0):
#     If (feature 3 <= 490.5)
#      If (feature 3 <= 207.5)
#       Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 6 <= 0.5)
#        Predict: 0.0
#       Else (feature 6 > 0.5)
#        If (feature 2 <= 21.5)
#         Predict: 0.0
#        Else (feature 2 > 21.5)
#         If (feature 2 <= 27.5)
#          Predict: 1.0
#         Else (feature 2 > 27.5)
#          Predict: 0.0
#     Else (feature 3 > 490.5)
#      If (feature 0 <= 59.5)
#       If (feature 0 <= 32.5)
#        If (feature 3 <= 695.5)
#         If (feature 5 <= -0.5)
#          Predict: 0.0
#         Else (feature 5 > -0.5)
#          Predict: 1.0
#        Else (feature 3 > 695.5)
#         If (feature 4 <= 14.5)
#          Predict: 1.0
#         Else (feature 4 > 14.5)
#          Predict: 0.0
#       Else (feature 0 > 32.5)
#        If (feature 5 <= 8.5)
#         If (feature 3 <= 913.0)
#          Predict: 0.0
#         Else (feature 3 > 913.0)
#          Predict: 1.0
#        Else (feature 5 > 8.5)
#         If (feature 5 <= 95.5)
#          Predict: 1.0
#         Else (feature 5 > 95.5)
#          Predict: 0.0
#      Else (feature 0 > 59.5)
#       If (feature 4 <= 11.5)
#        If (feature 6 <= 0.5)
#         If (feature 2 <= 15.5)
#          Predict: 1.0
#         Else (feature 2 > 15.5)
#          Predict: 0.0
#        Else (feature 6 > 0.5)
#         Predict: 1.0
#       Else (feature 4 > 11.5)
#        Predict: 0.0
#   Tree 3 (weight 1.0):
#     If (feature 5 <= 28.0)
#      If (feature 0 <= 59.5)
#       If (feature 3 <= 490.5)
#        Predict: 0.0
#       Else (feature 3 > 490.5)
#        If (feature 1 <= 1242.5)
#         If (feature 3 <= 913.0)
#          Predict: 0.0
#         Else (feature 3 > 913.0)
#          Predict: 1.0
#        Else (feature 1 > 1242.5)
#         If (feature 3 <= 695.5)
#          Predict: 0.0
#         Else (feature 3 > 695.5)
#          Predict: 1.0
#      Else (feature 0 > 59.5)
#       If (feature 3 <= 207.5)
#        Predict: 0.0
#       Else (feature 3 > 207.5)
#        If (feature 3 <= 695.5)
#         Predict: 0.0
#        Else (feature 3 > 695.5)
#         Predict: 1.0
#     Else (feature 5 > 28.0)
#      If (feature 2 <= 21.5)
#       If (feature 5 <= 95.5)
#        If (feature 4 <= 3.5)
#         If (feature 3 <= 168.5)
#          Predict: 0.0
#         Else (feature 3 > 168.5)
#          Predict: 1.0
#        Else (feature 4 > 3.5)
#         If (feature 3 <= 579.5)
#          Predict: 0.0
#         Else (feature 3 > 579.5)
#          Predict: 1.0
#       Else (feature 5 > 95.5)
#        Predict: 0.0
#      Else (feature 2 > 21.5)
#       If (feature 2 <= 27.5)
#        If (feature 0 <= 45.5)
#         If (feature 3 <= 180.5)
#          Predict: 0.0
#         Else (feature 3 > 180.5)
#          Predict: 1.0
#        Else (feature 0 > 45.5)
#         Predict: 0.0
#       Else (feature 2 > 27.5)
#        If (feature 3 <= 254.5)
#         Predict: 0.0
#        Else (feature 3 > 254.5)
#         If (feature 2 <= 29.5)
#          Predict: 0.0
#         Else (feature 2 > 29.5)
#          Predict: 1.0
#   Tree 4 (weight 1.0):
#     If (feature 3 <= 579.5)
#      If (feature 3 <= 207.5)
#       Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 5 <= 8.5)
#        Predict: 0.0
#       Else (feature 5 > 8.5)
#        If (feature 0 <= 59.5)
#         Predict: 0.0
#        Else (feature 0 > 59.5)
#         If (feature 1 <= 3804.0)
#          Predict: 1.0
#         Else (feature 1 > 3804.0)
#          Predict: 0.0
#     Else (feature 3 > 579.5)
#      If (feature 5 <= 8.5)
#       If (feature 3 <= 913.0)
#        If (feature 2 <= 16.5)
#         If (feature 0 <= 32.5)
#          Predict: 1.0
#         Else (feature 0 > 32.5)
#          Predict: 0.0
#        Else (feature 2 > 16.5)
#         Predict: 0.0
#       Else (feature 3 > 913.0)
#        Predict: 1.0
#      Else (feature 5 > 8.5)
#       If (feature 2 <= 21.5)
#        If (feature 6 <= 17.5)
#         If (feature 2 <= 15.5)
#          Predict: 1.0
#         Else (feature 2 > 15.5)
#          Predict: 0.0
#        Else (feature 6 > 17.5)
#         Predict: 1.0
#       Else (feature 2 > 21.5)
#        If (feature 5 <= 188.5)
#         Predict: 1.0
#        Else (feature 5 > 188.5)
#         If (feature 2 <= 29.5)
#          Predict: 1.0
#         Else (feature 2 > 29.5)
#          Predict: 0.0
#   Tree 5 (weight 1.0):
#     If (feature 5 <= 8.5)
#      If (feature 3 <= 579.5)
#       Predict: 0.0
#      Else (feature 3 > 579.5)
#       If (feature 2 <= 1.5)
#        If (feature 0 <= 52.5)
#         Predict: 1.0
#        Else (feature 0 > 52.5)
#         Predict: 0.0
#       Else (feature 2 > 1.5)
#        If (feature 3 <= 913.0)
#         Predict: 0.0
#        Else (feature 3 > 913.0)
#         Predict: 1.0
#     Else (feature 5 > 8.5)
#      If (feature 3 <= 207.5)
#       Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 0 <= 59.5)
#        If (feature 1 <= 930.5)
#         Predict: 0.0
#        Else (feature 1 > 930.5)
#         If (feature 3 <= 695.5)
#          Predict: 0.0
#         Else (feature 3 > 695.5)
#          Predict: 1.0
#       Else (feature 0 > 59.5)
#        Predict: 1.0
#   Tree 6 (weight 1.0):
#     If (feature 3 <= 579.5)
#      If (feature 6 <= 0.5)
#       Predict: 0.0
#      Else (feature 6 > 0.5)
#       If (feature 3 <= 168.5)
#        Predict: 0.0
#       Else (feature 3 > 168.5)
#        If (feature 2 <= 21.5)
#         If (feature 5 <= 95.5)
#          Predict: 1.0
#         Else (feature 5 > 95.5)
#          Predict: 0.0
#        Else (feature 2 > 21.5)
#         If (feature 2 <= 27.5)
#          Predict: 1.0
#         Else (feature 2 > 27.5)
#          Predict: 0.0
#     Else (feature 3 > 579.5)
#      If (feature 1 <= 1693.5)
#       If (feature 4 <= 1.5)
#        If (feature 3 <= 695.5)
#         If (feature 1 <= 102.5)
#          Predict: 1.0
#         Else (feature 1 > 102.5)
#          Predict: 0.0
#        Else (feature 3 > 695.5)
#         Predict: 1.0
#       Else (feature 4 > 1.5)
#        If (feature 3 <= 913.0)
#         Predict: 0.0
#        Else (feature 3 > 913.0)
#         If (feature 1 <= 9.5)
#          Predict: 0.0
#         Else (feature 1 > 9.5)
#          Predict: 1.0
#      Else (feature 1 > 1693.5)
#       If (feature 5 <= -0.5)
#        If (feature 0 <= 46.5)
#         Predict: 1.0
#        Else (feature 0 > 46.5)
#         Predict: 0.0
#       Else (feature 5 > -0.5)
#        If (feature 1 <= 3804.0)
#         If (feature 0 <= 34.5)
#          Predict: 0.0
#         Else (feature 0 > 34.5)
#          Predict: 1.0
#        Else (feature 1 > 3804.0)
#         Predict: 1.0
#   Tree 7 (weight 1.0):
#     If (feature 5 <= 8.5)
#      Predict: 0.0
#     Else (feature 5 > 8.5)
#      If (feature 2 <= 21.5)
#       If (feature 5 <= 95.5)
#        If (feature 3 <= 139.5)
#         Predict: 0.0
#        Else (feature 3 > 139.5)
#         If (feature 4 <= 4.5)
#          Predict: 1.0
#         Else (feature 4 > 4.5)
#          Predict: 0.0
#       Else (feature 5 > 95.5)
#        Predict: 0.0
#      Else (feature 2 > 21.5)
#       If (feature 2 <= 27.5)
#        If (feature 2 <= 23.5)
#         If (feature 3 <= 158.5)
#          Predict: 0.0
#         Else (feature 3 > 158.5)
#          Predict: 1.0
#        Else (feature 2 > 23.5)
#         If (feature 0 <= 26.5)
#          Predict: 1.0
#         Else (feature 0 > 26.5)
#          Predict: 0.0
#       Else (feature 2 > 27.5)
#        If (feature 0 <= 59.5)
#         Predict: 0.0
#        Else (feature 0 > 59.5)
#         Predict: 1.0
#   Tree 8 (weight 1.0):
#     If (feature 6 <= 0.5)
#      If (feature 3 <= 579.5)
#       If (feature 3 <= 350.5)
#        Predict: 0.0
#       Else (feature 3 > 350.5)
#        If (feature 3 <= 490.5)
#         If (feature 0 <= 59.5)
#          Predict: 0.0
#         Else (feature 0 > 59.5)
#          Predict: 1.0
#        Else (feature 3 > 490.5)
#         Predict: 0.0
#      Else (feature 3 > 579.5)
#       If (feature 0 <= 59.5)
#        If (feature 3 <= 913.0)
#         Predict: 0.0
#        Else (feature 3 > 913.0)
#         If (feature 0 <= 55.5)
#          Predict: 1.0
#         Else (feature 0 > 55.5)
#          Predict: 0.0
#       Else (feature 0 > 59.5)
#        If (feature 3 <= 913.0)
#         Predict: 1.0
#        Else (feature 3 > 913.0)
#         If (feature 2 <= 20.5)
#          Predict: 1.0
#         Else (feature 2 > 20.5)
#          Predict: 0.0
#     Else (feature 6 > 0.5)
#      If (feature 3 <= 207.5)
#       Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 5 <= 188.5)
#        If (feature 5 <= 95.5)
#         If (feature 1 <= 102.5)
#          Predict: 0.0
#         Else (feature 1 > 102.5)
#          Predict: 1.0
#        Else (feature 5 > 95.5)
#         If (feature 2 <= 21.5)
#          Predict: 0.0
#         Else (feature 2 > 21.5)
#          Predict: 1.0
#       Else (feature 5 > 188.5)
#        If (feature 3 <= 579.5)
#         Predict: 0.0
#        Else (feature 3 > 579.5)
#         If (feature 2 <= 6.5)
#          Predict: 0.0
#         Else (feature 2 > 6.5)
#          Predict: 1.0
#   Tree 9 (weight 1.0):
#     If (feature 3 <= 490.5)
#      If (feature 0 <= 59.5)
#       Predict: 0.0
#      Else (feature 0 > 59.5)
#       If (feature 5 <= 28.0)
#        If (feature 3 <= 207.5)
#         Predict: 0.0
#        Else (feature 3 > 207.5)
#         If (feature 3 <= 350.5)
#          Predict: 0.0
#         Else (feature 3 > 350.5)
#          Predict: 1.0
#       Else (feature 5 > 28.0)
#        If (feature 1 <= 0.5)
#         Predict: 0.0
#        Else (feature 1 > 0.5)
#         If (feature 3 <= 254.5)
#          Predict: 0.0
#         Else (feature 3 > 254.5)
#          Predict: 1.0
#     Else (feature 3 > 490.5)
#      If (feature 5 <= 8.5)
#       If (feature 1 <= 1076.5)
#        If (feature 2 <= 29.5)
#         Predict: 0.0
#        Else (feature 2 > 29.5)
#         If (feature 0 <= 53.5)
#          Predict: 1.0
#         Else (feature 0 > 53.5)
#          Predict: 0.0
#       Else (feature 1 > 1076.5)
#        If (feature 2 <= 14.5)
#         If (feature 0 <= 55.5)
#          Predict: 0.0
#         Else (feature 0 > 55.5)
#          Predict: 1.0
#        Else (feature 2 > 14.5)
#         Predict: 0.0
#      Else (feature 5 > 8.5)
#       If (feature 3 <= 695.5)
#        If (feature 4 <= 1.5)
#         Predict: 1.0
#        Else (feature 4 > 1.5)
#         If (feature 5 <= 95.5)
#          Predict: 1.0
#         Else (feature 5 > 95.5)
#          Predict: 0.0
#       Else (feature 3 > 695.5)
#        If (feature 2 <= 25.5)
#         If (feature 0 <= 55.5)
#          Predict: 1.0
#         Else (feature 0 > 55.5)
#          Predict: 0.0
#        Else (feature 2 > 25.5)
#         If (feature 5 <= 188.5)
#          Predict: 1.0
#         Else (feature 5 > 188.5)
#          Predict: 0.0
#   Tree 10 (weight 1.0):
#     If (feature 5 <= 9.5)
#      If (feature 3 <= 579.5)
#       Predict: 0.0
#      Else (feature 3 > 579.5)
#       If (feature 3 <= 913.0)
#        If (feature 3 <= 695.5)
#         Predict: 0.0
#        Else (feature 3 > 695.5)
#         If (feature 0 <= 32.5)
#          Predict: 1.0
#         Else (feature 0 > 32.5)
#          Predict: 0.0
#       Else (feature 3 > 913.0)
#        If (feature 4 <= 13.5)
#         Predict: 1.0
#        Else (feature 4 > 13.5)
#         If (feature 0 <= 38.5)
#          Predict: 0.0
#         Else (feature 0 > 38.5)
#          Predict: 1.0
#     Else (feature 5 > 9.5)
#      If (feature 2 <= 21.5)
#       If (feature 3 <= 180.5)
#        Predict: 0.0
#       Else (feature 3 > 180.5)
#        If (feature 5 <= 95.5)
#         If (feature 4 <= 4.5)
#          Predict: 1.0
#         Else (feature 4 > 4.5)
#          Predict: 0.0
#        Else (feature 5 > 95.5)
#         Predict: 0.0
#      Else (feature 2 > 21.5)
#       If (feature 1 <= -0.5)
#        Predict: 0.0
#       Else (feature 1 > -0.5)
#        If (feature 3 <= 168.5)
#         Predict: 0.0
#        Else (feature 3 > 168.5)
#         If (feature 5 <= 188.5)
#          Predict: 1.0
#         Else (feature 5 > 188.5)
#          Predict: 0.0
#   Tree 11 (weight 1.0):
#     If (feature 3 <= 490.5)
#      If (feature 5 <= 12.5)
#       If (feature 3 <= 207.5)
#        Predict: 0.0
#       Else (feature 3 > 207.5)
#        If (feature 0 <= 59.5)
#         Predict: 0.0
#        Else (feature 0 > 59.5)
#         If (feature 2 <= 2.5)
#          Predict: 1.0
#         Else (feature 2 > 2.5)
#          Predict: 0.0
#      Else (feature 5 > 12.5)
#       If (feature 3 <= 168.5)
#        Predict: 0.0
#       Else (feature 3 > 168.5)
#        If (feature 2 <= 21.5)
#         If (feature 5 <= 95.5)
#          Predict: 1.0
#         Else (feature 5 > 95.5)
#          Predict: 0.0
#        Else (feature 2 > 21.5)
#         If (feature 2 <= 27.5)
#          Predict: 1.0
#         Else (feature 2 > 27.5)
#          Predict: 0.0
#     Else (feature 3 > 490.5)
#      If (feature 6 <= 0.5)
#       If (feature 0 <= 59.5)
#        If (feature 1 <= 1242.5)
#         If (feature 3 <= 913.0)
#          Predict: 0.0
#         Else (feature 3 > 913.0)
#          Predict: 1.0
#        Else (feature 1 > 1242.5)
#         If (feature 4 <= 5.5)
#          Predict: 0.0
#         Else (feature 4 > 5.5)
#          Predict: 1.0
#       Else (feature 0 > 59.5)
#        If (feature 4 <= 2.5)
#         If (feature 2 <= 5.5)
#          Predict: 0.0
#         Else (feature 2 > 5.5)
#          Predict: 1.0
#        Else (feature 4 > 2.5)
#         If (feature 2 <= 5.5)
#          Predict: 1.0
#         Else (feature 2 > 5.5)
#          Predict: 0.0
#      Else (feature 6 > 0.5)
#       If (feature 2 <= 21.5)
#        If (feature 5 <= 95.5)
#         If (feature 1 <= 0.5)
#          Predict: 0.0
#         Else (feature 1 > 0.5)
#          Predict: 1.0
#        Else (feature 5 > 95.5)
#         If (feature 3 <= 913.0)
#          Predict: 0.0
#         Else (feature 3 > 913.0)
#          Predict: 1.0
#       Else (feature 2 > 21.5)
#        If (feature 2 <= 28.5)
#         Predict: 1.0
#        Else (feature 2 > 28.5)
#         If (feature 1 <= -80.0)
#          Predict: 0.0
#         Else (feature 1 > -80.0)
#          Predict: 1.0
#   Tree 12 (weight 1.0):
#     If (feature 5 <= 8.5)
#      If (feature 3 <= 579.5)
#       If (feature 2 <= 3.5)
#        If (feature 2 <= 1.5)
#         If (feature 0 <= 26.5)
#          Predict: 1.0
#         Else (feature 0 > 26.5)
#          Predict: 0.0
#        Else (feature 2 > 1.5)
#         Predict: 0.0
#       Else (feature 2 > 3.5)
#        Predict: 0.0
#      Else (feature 3 > 579.5)
#       If (feature 3 <= 913.0)
#        If (feature 3 <= 695.5)
#         Predict: 0.0
#        Else (feature 3 > 695.5)
#         If (feature 0 <= 31.5)
#          Predict: 1.0
#         Else (feature 0 > 31.5)
#          Predict: 0.0
#       Else (feature 3 > 913.0)
#        If (feature 2 <= 14.5)
#         Predict: 1.0
#        Else (feature 2 > 14.5)
#         If (feature 0 <= 55.5)
#          Predict: 1.0
#         Else (feature 0 > 55.5)
#          Predict: 0.0
#     Else (feature 5 > 8.5)
#      If (feature 2 <= 21.5)
#       If (feature 3 <= 207.5)
#        Predict: 0.0
#       Else (feature 3 > 207.5)
#        If (feature 3 <= 432.5)
#         If (feature 5 <= 95.5)
#          Predict: 1.0
#         Else (feature 5 > 95.5)
#          Predict: 0.0
#        Else (feature 3 > 432.5)
#         If (feature 2 <= 16.5)
#          Predict: 1.0
#         Else (feature 2 > 16.5)
#          Predict: 0.0
#      Else (feature 2 > 21.5)
#       If (feature 3 <= 168.5)
#        Predict: 0.0
#       Else (feature 3 > 168.5)
#        If (feature 2 <= 25.5)
#         If (feature 3 <= 207.5)
#          Predict: 0.0
#         Else (feature 3 > 207.5)
#          Predict: 1.0
#        Else (feature 2 > 25.5)
#         If (feature 3 <= 579.5)
#          Predict: 0.0
#         Else (feature 3 > 579.5)
#          Predict: 1.0
#   Tree 13 (weight 1.0):
#     If (feature 5 <= 8.5)
#      If (feature 4 <= 1.5)
#       If (feature 1 <= 280.5)
#        If (feature 3 <= 490.5)
#         Predict: 0.0
#        Else (feature 3 > 490.5)
#         If (feature 2 <= 29.5)
#          Predict: 0.0
#         Else (feature 2 > 29.5)
#          Predict: 1.0
#       Else (feature 1 > 280.5)
#        If (feature 2 <= 1.5)
#         If (feature 3 <= 180.5)
#          Predict: 0.0
#         Else (feature 3 > 180.5)
#          Predict: 1.0
#        Else (feature 2 > 1.5)
#         Predict: 0.0
#      Else (feature 4 > 1.5)
#       If (feature 0 <= 59.5)
#        Predict: 0.0
#       Else (feature 0 > 59.5)
#        If (feature 3 <= 207.5)
#         Predict: 0.0
#        Else (feature 3 > 207.5)
#         If (feature 2 <= 1.5)
#          Predict: 1.0
#         Else (feature 2 > 1.5)
#          Predict: 0.0
#     Else (feature 5 > 8.5)
#      If (feature 5 <= 95.5)
#       If (feature 3 <= 139.5)
#        If (feature 1 <= 7596.5)
#         Predict: 0.0
#        Else (feature 1 > 7596.5)
#         If (feature 3 <= 103.5)
#          Predict: 1.0
#         Else (feature 3 > 103.5)
#          Predict: 0.0
#       Else (feature 3 > 139.5)
#        If (feature 3 <= 207.5)
#         If (feature 4 <= 1.5)
#          Predict: 1.0
#         Else (feature 4 > 1.5)
#          Predict: 0.0
#        Else (feature 3 > 207.5)
#         If (feature 4 <= 6.5)
#          Predict: 1.0
#         Else (feature 4 > 6.5)
#          Predict: 0.0
#      Else (feature 5 > 95.5)
#       If (feature 5 <= 188.5)
#        If (feature 3 <= 180.5)
#         Predict: 0.0
#        Else (feature 3 > 180.5)
#         If (feature 5 <= 165.5)
#          Predict: 0.0
#         Else (feature 5 > 165.5)
#          Predict: 1.0
#       Else (feature 5 > 188.5)
#        Predict: 0.0
#   Tree 14 (weight 1.0):
#     If (feature 5 <= 8.5)
#      If (feature 3 <= 579.5)
#       If (feature 0 <= 59.5)
#        Predict: 0.0
#       Else (feature 0 > 59.5)
#        If (feature 4 <= 3.5)
#         Predict: 0.0
#        Else (feature 4 > 3.5)
#         If (feature 3 <= 432.5)
#          Predict: 0.0
#         Else (feature 3 > 432.5)
#          Predict: 1.0
#      Else (feature 3 > 579.5)
#       If (feature 1 <= 1076.5)
#        If (feature 1 <= 686.5)
#         If (feature 3 <= 913.0)
#          Predict: 0.0
#         Else (feature 3 > 913.0)
#          Predict: 1.0
#        Else (feature 1 > 686.5)
#         Predict: 0.0
#       Else (feature 1 > 1076.5)
#        If (feature 3 <= 695.5)
#         If (feature 0 <= 25.5)
#          Predict: 1.0
#         Else (feature 0 > 25.5)
#          Predict: 0.0
#        Else (feature 3 > 695.5)
#         Predict: 1.0
#     Else (feature 5 > 8.5)
#      If (feature 3 <= 207.5)
#       Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 5 <= 188.5)
#        If (feature 5 <= 95.5)
#         Predict: 1.0
#        Else (feature 5 > 95.5)
#         If (feature 2 <= 21.5)
#          Predict: 0.0
#         Else (feature 2 > 21.5)
#          Predict: 1.0
#       Else (feature 5 > 188.5)
#        If (feature 3 <= 579.5)
#         If (feature 0 <= 59.5)
#          Predict: 0.0
#         Else (feature 0 > 59.5)
#          Predict: 1.0
#        Else (feature 3 > 579.5)
#         If (feature 0 <= 29.5)
#          Predict: 0.0
#         Else (feature 0 > 29.5)
#          Predict: 1.0
#   Tree 15 (weight 1.0):
#     If (feature 5 <= 8.5)
#      If (feature 1 <= 69.5)
#       If (feature 0 <= 29.5)
#        If (feature 3 <= 385.5)
#         Predict: 0.0
#        Else (feature 3 > 385.5)
#         If (feature 3 <= 695.5)
#          Predict: 0.0
#         Else (feature 3 > 695.5)
#          Predict: 1.0
#       Else (feature 0 > 29.5)
#        Predict: 0.0
#      Else (feature 1 > 69.5)
#       Predict: 0.0
#     Else (feature 5 > 8.5)
#      If (feature 3 <= 207.5)
#       Predict: 0.0
#      Else (feature 3 > 207.5)
#       If (feature 5 <= 188.5)
#        If (feature 5 <= 95.5)
#         If (feature 4 <= 3.5)
#          Predict: 1.0
#         Else (feature 4 > 3.5)
#          Predict: 0.0
#        Else (feature 5 > 95.5)
#         If (feature 0 <= 59.5)
#          Predict: 0.0
#         Else (feature 0 > 59.5)
#          Predict: 1.0
#       Else (feature 5 > 188.5)
#        If (feature 1 <= 1428.5)
#         Predict: 0.0
#        Else (feature 1 > 1428.5)
#         If (feature 2 <= 20.5)
#          Predict: 0.0
#         Else (feature 2 > 20.5)
#          Predict: 1.0
#   Tree 16 (weight 1.0):
#     If (feature 6 <= 0.5)
#      If (feature 0 <= 59.5)
#       If (feature 0 <= 28.5)
#        If (feature 1 <= 280.5)
#         Predict: 0.0
#        Else (feature 1 > 280.5)
#         If (feature 3 <= 695.5)
#          Predict: 0.0
#         Else (feature 3 > 695.5)
#          Predict: 1.0
#       Else (feature 0 > 28.5)
#        Predict: 0.0
#      Else (feature 0 > 59.5)
#       If (feature 3 <= 207.5)
#        Predict: 0.0
#       Else (feature 3 > 207.5)
#        If (feature 3 <= 350.5)
#         Predict: 0.0
#        Else (feature 3 > 350.5)
#         If (feature 1 <= 328.5)
#          Predict: 0.0
#         Else (feature 1 > 328.5)
#          Predict: 1.0
#     Else (feature 6 > 0.5)
#      If (feature 3 <= 180.5)
#       Predict: 0.0
#      Else (feature 3 > 180.5)
#       If (feature 1 <= -0.5)
#        If (feature 2 <= 1.5)
#         Predict: 1.0
#        Else (feature 2 > 1.5)
#         If (feature 3 <= 579.5)
#          Predict: 0.0
#         Else (feature 3 > 579.5)
#          Predict: 1.0
#       Else (feature 1 > -0.5)
#        If (feature 5 <= 188.5)
#         If (feature 2 <= 21.5)
#          Predict: 0.0
#         Else (feature 2 > 21.5)
#          Predict: 1.0
#        Else (feature 5 > 188.5)
#         Predict: 0.0
#   Tree 17 (weight 1.0):
#     If (feature 6 <= 0.5)
#      If (feature 0 <= 59.5)
#       If (feature 3 <= 579.5)
#        Predict: 0.0
#       Else (feature 3 > 579.5)
#        If (feature 3 <= 695.5)
#         Predict: 0.0
#        Else (feature 3 > 695.5)
#         Predict: 1.0
#      Else (feature 0 > 59.5)
#       If (feature 4 <= 3.5)
#        If (feature 1 <= 7596.5)
#         If (feature 3 <= 295.5)
#          Predict: 0.0
#         Else (feature 3 > 295.5)
#          Predict: 1.0
#        Else (feature 1 > 7596.5)
#         Predict: 0.0
#       Else (feature 4 > 3.5)
#        If (feature 1 <= 1428.5)
#         Predict: 0.0
#        Else (feature 1 > 1428.5)
#         If (feature 3 <= 192.5)
#          Predict: 0.0
#         Else (feature 3 > 192.5)
#          Predict: 1.0
#     Else (feature 6 > 0.5)
#      If (feature 5 <= 188.5)
#       If (feature 5 <= 95.5)
#        If (feature 3 <= 158.5)
#         Predict: 0.0
#        Else (feature 3 > 158.5)
#         If (feature 5 <= 36.0)
#          Predict: 0.0
#         Else (feature 5 > 36.0)
#          Predict: 1.0
#       Else (feature 5 > 95.5)
#        If (feature 2 <= 21.5)
#         Predict: 0.0
#        Else (feature 2 > 21.5)
#         If (feature 3 <= 180.5)
#          Predict: 0.0
#         Else (feature 3 > 180.5)
#          Predict: 1.0
#      Else (feature 5 > 188.5)
#       If (feature 3 <= 350.5)
#        Predict: 0.0
#       Else (feature 3 > 350.5)
#        If (feature 1 <= 597.5)
#         If (feature 0 <= 59.5)
#          Predict: 0.0
#         Else (feature 0 > 59.5)
#          Predict: 1.0
#        Else (feature 1 > 597.5)
#         If (feature 4 <= 1.5)
#          Predict: 1.0
#         Else (feature 4 > 1.5)
#          Predict: 0.0
#   Tree 18 (weight 1.0):
#     If (feature 5 <= 8.5)
#      If (feature 3 <= 490.5)
#       Predict: 0.0
#      Else (feature 3 > 490.5)
#       If (feature 3 <= 913.0)
#        Predict: 0.0
#       Else (feature 3 > 913.0)
#        If (feature 2 <= 1.5)
#         Predict: 1.0
#        Else (feature 2 > 1.5)
#         If (feature 6 <= 0.5)
#          Predict: 1.0
#         Else (feature 6 > 0.5)
#          Predict: 0.0
#     Else (feature 5 > 8.5)
#      If (feature 5 <= 95.5)
#       If (feature 4 <= 4.5)
#        If (feature 3 <= 149.5)
#         Predict: 0.0
#        Else (feature 3 > 149.5)
#         If (feature 2 <= 2.5)
#          Predict: 0.0
#         Else (feature 2 > 2.5)
#          Predict: 1.0
#       Else (feature 4 > 4.5)
#        If (feature 3 <= 221.5)
#         Predict: 0.0
#        Else (feature 3 > 221.5)
#         If (feature 1 <= 686.5)
#          Predict: 1.0
#         Else (feature 1 > 686.5)
#          Predict: 0.0
#      Else (feature 5 > 95.5)
#       If (feature 3 <= 254.5)
#        Predict: 0.0
#       Else (feature 3 > 254.5)
#        If (feature 3 <= 490.5)
#         Predict: 0.0
#        Else (feature 3 > 490.5)
#         If (feature 1 <= -80.0)
#          Predict: 0.0
#         Else (feature 1 > -80.0)
#          Predict: 1.0
#   Tree 19 (weight 1.0):
#     If (feature 0 <= 59.5)
#      If (feature 3 <= 490.5)
#       If (feature 6 <= 0.5)
#        Predict: 0.0
#       Else (feature 6 > 0.5)
#        If (feature 0 <= 25.5)
#         If (feature 3 <= 180.5)
#          Predict: 0.0
#         Else (feature 3 > 180.5)
#          Predict: 1.0
#        Else (feature 0 > 25.5)
#         Predict: 0.0
#      Else (feature 3 > 490.5)
#       If (feature 3 <= 695.5)
#        If (feature 5 <= 8.5)
#         Predict: 0.0
#        Else (feature 5 > 8.5)
#         If (feature 5 <= 95.5)
#          Predict: 1.0
#         Else (feature 5 > 95.5)
#          Predict: 0.0
#       Else (feature 3 > 695.5)
#        If (feature 3 <= 913.0)
#         If (feature 6 <= 0.5)
#          Predict: 0.0
#         Else (feature 6 > 0.5)
#          Predict: 1.0
#        Else (feature 3 > 913.0)
#         Predict: 1.0
#     Else (feature 0 > 59.5)
#      If (feature 3 <= 207.5)
#       If (feature 5 <= 14.5)
#        Predict: 0.0
#       Else (feature 5 > 14.5)
#        If (feature 6 <= 6.5)
#         Predict: 0.0
#        Else (feature 6 > 6.5)
#         If (feature 5 <= 165.5)
#          Predict: 0.0
#         Else (feature 5 > 165.5)
#          Predict: 1.0
#      Else (feature 3 > 207.5)
#       If (feature 6 <= 0.5)
#        If (feature 2 <= 24.5)
#         If (feature 3 <= 913.0)
#          Predict: 0.0
#         Else (feature 3 > 913.0)
#          Predict: 1.0
#        Else (feature 2 > 24.5)
#         If (feature 1 <= 280.5)
#          Predict: 0.0
#         Else (feature 1 > 280.5)
#          Predict: 1.0
#       Else (feature 6 > 0.5)
#        If (feature 2 <= 2.5)
#         If (feature 1 <= 142.5)
#          Predict: 1.0
#         Else (feature 1 > 142.5)
#          Predict: 0.0
#        Else (feature 2 > 2.5)
#         Predict: 1.0

# %%
from pyspark.ml.regression import RandomForestRegressor

reg = RandomForestRegressor(featuresCol='features', labelCol='balance')
reg_model = reg.fit(continuous_df)
print(reg_model.featureImportances)
print(reg_model.toDebugString)
# Out:
# (6,[0,1,2,3,4,5],[0.41892201462152007,0.21670083472491117,0.10765896383704084,0.06965690771303537,0.10482267536078857,0.08223860374270413])
# RandomForestRegressionModel (uid=RandomForestRegressor_bbf6bb4d5022) with 20 trees
#   Tree 0 (weight 1.0):
#     If (feature 1 <= 21.5)
#      If (feature 1 <= 18.5)
#       If (feature 5 <= 2.5)
#        If (feature 0 <= 50.5)
#         If (feature 0 <= 35.5)
#          Predict: 1048.641155545974
#         Else (feature 0 > 35.5)
#          Predict: 1275.4021535580525
#        Else (feature 0 > 50.5)
#         If (feature 3 <= 17.5)
#          Predict: 1775.0430576631259
#         Else (feature 3 > 17.5)
#          Predict: 5520.434782608696
#       Else (feature 5 > 2.5)
#        If (feature 1 <= 1.5)
#         If (feature 5 <= 3.5)
#          Predict: 8022.733333333334
#         Else (feature 5 > 3.5)
#          Predict: 2771.757575757576
#        Else (feature 1 > 1.5)
#         If (feature 1 <= 6.5)
#          Predict: 1141.8323782234957
#         Else (feature 1 > 6.5)
#          Predict: 1676.2885747938751
#      Else (feature 1 > 18.5)
#       If (feature 5 <= 2.5)
#        If (feature 0 <= 29.5)
#         If (feature 3 <= 2.5)
#          Predict: 752.5324074074074
#         Else (feature 3 > 2.5)
#          Predict: 389.31775700934577
#        Else (feature 0 > 29.5)
#         If (feature 3 <= 29.5)
#          Predict: 1942.2858627858627
#         Else (feature 3 > 29.5)
#          Predict: 18096.6
#       Else (feature 5 > 2.5)
#        If (feature 5 <= 4.5)
#         If (feature 2 <= 101.5)
#          Predict: 4536.047619047619
#         Else (feature 2 > 101.5)
#          Predict: 2132.7457627118642
#        Else (feature 5 > 4.5)
#         If (feature 2 <= 475.5)
#          Predict: 1812.0567375886526
#         Else (feature 2 > 475.5)
#          Predict: 3791.1052631578946
#     Else (feature 1 > 21.5)
#      If (feature 4 <= 31.5)
#       If (feature 1 <= 28.5)
#        If (feature 2 <= 287.5)
#         If (feature 3 <= 2.5)
#          Predict: 835.6670707070707
#         Else (feature 3 > 2.5)
#          Predict: 1096.264458955224
#        Else (feature 2 > 287.5)
#         If (feature 0 <= 53.5)
#          Predict: 978.6863699582753
#         Else (feature 0 > 53.5)
#          Predict: 1799.5021459227469
#       Else (feature 1 > 28.5)
#        If (feature 0 <= 40.5)
#         If (feature 3 <= 1.5)
#          Predict: 1215.8458149779735
#         Else (feature 3 > 1.5)
#          Predict: 899.1420265780731
#        Else (feature 0 > 40.5)
#         If (feature 5 <= 0.5)
#          Predict: 1530.2321630804076
#         Else (feature 5 > 0.5)
#          Predict: 540.7142857142857
#      Else (feature 4 > 31.5)
#       If (feature 1 <= 26.5)
#        If (feature 5 <= 6.5)
#         If (feature 0 <= 41.5)
#          Predict: 1753.8333333333333
#         Else (feature 0 > 41.5)
#          Predict: 3176.7242990654204
#        Else (feature 5 > 6.5)
#         If (feature 1 <= 22.5)
#          Predict: 1880.5
#         Else (feature 1 > 22.5)
#          Predict: 1046.9583333333333
#       Else (feature 1 > 26.5)
#        If (feature 0 <= 60.5)
#         If (feature 0 <= 30.5)
#          Predict: 881.3974358974359
#         Else (feature 0 > 30.5)
#          Predict: 1359.251736111111
#        Else (feature 0 > 60.5)
#         If (feature 1 <= 28.5)
#          Predict: 6031.736842105263
#         Else (feature 1 > 28.5)
#          Predict: 1610.7407407407406
#   Tree 1 (weight 1.0):
#     If (feature 4 <= 22.5)
#      If (feature 1 <= 21.5)
#       If (feature 1 <= 17.5)
#        If (feature 3 <= 5.5)
#         If (feature 1 <= 1.5)
#          Predict: 2393.362244897959
#         Else (feature 1 > 1.5)
#          Predict: 1248.381535816003
#        Else (feature 3 > 5.5)
#         If (feature 0 <= 53.5)
#          Predict: 1419.0400326797385
#         Else (feature 0 > 53.5)
#          Predict: 2194.0518134715026
#       Else (feature 1 > 17.5)
#        If (feature 3 <= 30.5)
#         If (feature 4 <= 7.5)
#          Predict: 1798.4847872913301
#         Else (feature 4 > 7.5)
#          Predict: 4099.5
#        Else (feature 3 > 30.5)
#         If (feature 0 <= 38.5)
#          Predict: 23135.5
#         Else (feature 0 > 38.5)
#          Predict: 990.75
#      Else (feature 1 > 21.5)
#       If (feature 1 <= 28.5)
#        If (feature 0 <= 60.5)
#         If (feature 2 <= 287.5)
#          Predict: 876.0699330887114
#         Else (feature 2 > 287.5)
#          Predict: 1042.6804252657912
#        Else (feature 0 > 60.5)
#         If (feature 3 <= 5.5)
#          Predict: 2108.4273504273506
#         Else (feature 3 > 5.5)
#          Predict: 7101.666666666667
#       Else (feature 1 > 28.5)
#        If (feature 4 <= -0.5)
#         Predict: 1252.9664331582019
#        Else (feature 4 > -0.5)
#         If (feature 2 <= 174.5)
#          Predict: 131.8181818181818
#         Else (feature 2 > 174.5)
#          Predict: 781.6
#     Else (feature 4 > 22.5)
#      If (feature 3 <= 5.5)
#       If (feature 2 <= 126.5)
#        If (feature 1 <= 17.5)
#         If (feature 0 <= 56.5)
#          Predict: 1061.3570822731128
#         Else (feature 0 > 56.5)
#          Predict: 2023.7555555555555
#        Else (feature 1 > 17.5)
#         If (feature 0 <= 54.5)
#          Predict: 1604.8650217706822
#         Else (feature 0 > 54.5)
#          Predict: 2494.7444444444445
#       Else (feature 2 > 126.5)
#        If (feature 1 <= 18.5)
#         If (feature 4 <= 188.5)
#          Predict: 1980.8044092707744
#         Else (feature 4 > 188.5)
#          Predict: 1070.0122985581002
#        Else (feature 1 > 18.5)
#         If (feature 1 <= 26.5)
#          Predict: 2320.7084188911704
#         Else (feature 1 > 26.5)
#          Predict: 1826.7504393673112
#      Else (feature 3 > 5.5)
#       If (feature 4 <= 188.5)
#        If (feature 2 <= 312.5)
#         If (feature 2 <= 287.5)
#          Predict: 1427.7105263157894
#         Else (feature 2 > 287.5)
#          Predict: 6046.0
#        Else (feature 2 > 312.5)
#         If (feature 2 <= 676.5)
#          Predict: 636.0952380952381
#         Else (feature 2 > 676.5)
#          Predict: 1819.3333333333333
#       Else (feature 4 > 188.5)
#        If (feature 3 <= 9.5)
#         If (feature 1 <= 19.5)
#          Predict: 666.8625
#         Else (feature 1 > 19.5)
#          Predict: 1898.7916666666667
#        Else (feature 3 > 9.5)
#         If (feature 0 <= 40.5)
#          Predict: -26.6875
#         Else (feature 0 > 40.5)
#          Predict: 770.6666666666666
#   Tree 2 (weight 1.0):
#     If (feature 1 <= 21.5)
#      If (feature 0 <= 53.5)
#       If (feature 4 <= 280.5)
#        If (feature 2 <= 417.5)
#         If (feature 1 <= 18.5)
#          Predict: 1159.3730412805392
#         Else (feature 1 > 18.5)
#          Predict: 1830.4082840236686
#        Else (feature 2 > 417.5)
#         If (feature 1 <= 17.5)
#          Predict: 1383.0146326276463
#         Else (feature 1 > 17.5)
#          Predict: 1923.6157989228006
#       Else (feature 4 > 280.5)
#        If (feature 3 <= 1.5)
#         If (feature 0 <= 45.5)
#          Predict: 1154.847311827957
#         Else (feature 0 > 45.5)
#          Predict: 1682.5081081081082
#        Else (feature 3 > 1.5)
#         If (feature 5 <= 3.5)
#          Predict: 943.4418604651163
#         Else (feature 5 > 3.5)
#          Predict: 569.2390670553935
#      Else (feature 0 > 53.5)
#       If (feature 0 <= 60.5)
#        If (feature 4 <= 188.5)
#         If (feature 5 <= 1.5)
#          Predict: 1958.8955308852833
#         Else (feature 5 > 1.5)
#          Predict: 2736.6072874493925
#        Else (feature 4 > 188.5)
#         If (feature 2 <= 676.5)
#          Predict: 1217.342105263158
#         Else (feature 2 > 676.5)
#          Predict: 2660.2631578947367
#       Else (feature 0 > 60.5)
#        If (feature 4 <= 188.5)
#         If (feature 2 <= 378.5)
#          Predict: 2151.0580431177445
#         Else (feature 2 > 378.5)
#          Predict: 4038.737288135593
#        Else (feature 4 > 188.5)
#         If (feature 2 <= 378.5)
#          Predict: 2781.925
#         Else (feature 2 > 378.5)
#          Predict: 9654.214285714286
#     Else (feature 1 > 21.5)
#      If (feature 5 <= 0.5)
#       If (feature 0 <= 60.5)
#        If (feature 0 <= 46.5)
#         If (feature 2 <= 101.5)
#          Predict: 884.5729591836734
#         Else (feature 2 > 101.5)
#          Predict: 1034.779408847451
#        Else (feature 0 > 46.5)
#         If (feature 3 <= 21.5)
#          Predict: 1270.8158803222095
#         Else (feature 3 > 21.5)
#          Predict: 628.9166666666666
#       Else (feature 0 > 60.5)
#        If (feature 3 <= 3.5)
#         If (feature 1 <= 29.5)
#          Predict: 2198.2266666666665
#         Else (feature 1 > 29.5)
#          Predict: 4895.294117647059
#        Else (feature 3 > 3.5)
#         Predict: 856.4583333333334
#      Else (feature 5 > 0.5)
#       If (feature 0 <= 54.5)
#        If (feature 1 <= 26.5)
#         If (feature 4 <= 280.5)
#          Predict: 2472.158249158249
#         Else (feature 4 > 280.5)
#          Predict: 1517.5901639344263
#        Else (feature 1 > 26.5)
#         If (feature 5 <= 2.5)
#          Predict: 1189.3895781637716
#         Else (feature 5 > 2.5)
#          Predict: 1384.4805653710248
#       Else (feature 0 > 54.5)
#        If (feature 0 <= 56.5)
#         If (feature 1 <= 23.5)
#          Predict: 8778.846153846154
#         Else (feature 1 > 23.5)
#          Predict: 1763.4347826086957
#        Else (feature 0 > 56.5)
#         If (feature 2 <= 246.5)
#          Predict: 1562.5964912280701
#         Else (feature 2 > 246.5)
#          Predict: 2741.3217391304347
#   Tree 3 (weight 1.0):
#     If (feature 5 <= 0.5)
#      If (feature 1 <= 21.5)
#       If (feature 0 <= 54.5)
#        If (feature 0 <= 29.5)
#         If (feature 2 <= 287.5)
#          Predict: 906.8213748118415
#         Else (feature 2 > 287.5)
#          Predict: 716.9632206759443
#        Else (feature 0 > 29.5)
#         If (feature 0 <= 42.5)
#          Predict: 1255.1505830009205
#         Else (feature 0 > 42.5)
#          Predict: 1544.1969066805302
#       Else (feature 0 > 54.5)
#        If (feature 3 <= 4.5)
#         If (feature 0 <= 60.5)
#          Predict: 1932.342438638163
#         Else (feature 0 > 60.5)
#          Predict: 2766.5920138888887
#        Else (feature 3 > 4.5)
#         If (feature 2 <= 163.5)
#          Predict: 3585.131067961165
#         Else (feature 2 > 163.5)
#          Predict: 1599.0290697674418
#      Else (feature 1 > 21.5)
#       If (feature 0 <= 46.5)
#        Predict: 943.6610266704904
#       Else (feature 0 > 46.5)
#        If (feature 0 <= 60.5)
#         If (feature 2 <= 42.5)
#          Predict: 1022.2836538461538
#         Else (feature 2 > 42.5)
#          Predict: 1365.494763301215
#        Else (feature 0 > 60.5)
#         If (feature 2 <= 143.5)
#          Predict: 1115.0454545454545
#         Else (feature 2 > 143.5)
#          Predict: 2443.087591240876
#     Else (feature 5 > 0.5)
#      If (feature 4 <= 188.5)
#       If (feature 1 <= 1.5)
#        If (feature 2 <= 378.5)
#         If (feature 3 <= 5.5)
#          Predict: 1754.4098360655737
#         Else (feature 3 > 5.5)
#          Predict: 5335.333333333333
#        Else (feature 2 > 378.5)
#         If (feature 0 <= 60.5)
#          Predict: 712.8
#         Else (feature 0 > 60.5)
#          Predict: 21771.375
#       Else (feature 1 > 1.5)
#        If (feature 4 <= 30.0)
#         If (feature 0 <= 60.5)
#          Predict: 686.361963190184
#         Else (feature 0 > 60.5)
#          Predict: 1885.75
#        Else (feature 4 > 30.0)
#         If (feature 1 <= 26.5)
#          Predict: 2009.9963122311
#         Else (feature 1 > 26.5)
#          Predict: 1476.5295629820052
#      Else (feature 4 > 188.5)
#       If (feature 5 <= 1.5)
#        If (feature 0 <= 60.5)
#         If (feature 0 <= 32.5)
#          Predict: 944.8211009174312
#         Else (feature 0 > 32.5)
#          Predict: 1327.6888694127958
#        Else (feature 0 > 60.5)
#         If (feature 1 <= 15.5)
#          Predict: 10935.25
#         Else (feature 1 > 15.5)
#          Predict: 2995.4
#       Else (feature 5 > 1.5)
#        If (feature 3 <= 1.5)
#         If (feature 0 <= 54.5)
#          Predict: 1231.2339585389932
#         Else (feature 0 > 54.5)
#          Predict: 1915.4392523364486
#        Else (feature 3 > 1.5)
#         If (feature 0 <= 60.5)
#          Predict: 942.1161745827984
#         Else (feature 0 > 60.5)
#          Predict: 4058.88
#   Tree 4 (weight 1.0):
#     If (feature 1 <= 21.5)
#      If (feature 0 <= 50.5)
#       If (feature 1 <= 17.5)
#        If (feature 0 <= 35.5)
#         If (feature 4 <= 27.5)
#          Predict: 907.9606924932596
#         Else (feature 4 > 27.5)
#          Predict: 1310.368293861769
#        Else (feature 0 > 35.5)
#         If (feature 4 <= 188.5)
#          Predict: 1267.7842846553003
#         Else (feature 4 > 188.5)
#          Predict: 989.069105691057
#       Else (feature 1 > 17.5)
#        If (feature 0 <= 28.5)
#         If (feature 5 <= 8.5)
#          Predict: 943.1484230055659
#         Else (feature 5 > 8.5)
#          Predict: 6442.666666666667
#        Else (feature 0 > 28.5)
#         If (feature 1 <= 19.5)
#          Predict: 1603.4444444444443
#         Else (feature 1 > 19.5)
#          Predict: 1795.7622863247864
#      Else (feature 0 > 50.5)
#       If (feature 4 <= 280.5)
#        If (feature 0 <= 58.5)
#         If (feature 5 <= 18.5)
#          Predict: 1773.3751071122535
#         Else (feature 5 > 18.5)
#          Predict: 12838.333333333334
#        Else (feature 0 > 58.5)
#         If (feature 3 <= 4.5)
#          Predict: 2492.333740085418
#         Else (feature 3 > 4.5)
#          Predict: 4098.231292517007
#       Else (feature 4 > 280.5)
#        If (feature 4 <= 349.5)
#         If (feature 3 <= 2.5)
#          Predict: 980.1111111111111
#         Else (feature 3 > 2.5)
#          Predict: 226.16216216216216
#        Else (feature 4 > 349.5)
#         If (feature 1 <= 7.5)
#          Predict: 2324.5714285714284
#         Else (feature 1 > 7.5)
#          Predict: 1296.7338129496402
#     Else (feature 1 > 21.5)
#      If (feature 4 <= 22.5)
#       If (feature 1 <= 28.5)
#        If (feature 3 <= 3.5)
#         If (feature 0 <= 60.5)
#          Predict: 902.8351756325227
#         Else (feature 0 > 60.5)
#          Predict: 2321.7421875
#        Else (feature 3 > 3.5)
#         If (feature 3 <= 23.5)
#          Predict: 1131.3430761859129
#         Else (feature 3 > 23.5)
#          Predict: 434.8285714285714
#       Else (feature 1 > 28.5)
#        If (feature 1 <= 29.5)
#         If (feature 0 <= 50.5)
#          Predict: 979.4677558039552
#         Else (feature 0 > 50.5)
#          Predict: 1787.6656151419559
#        Else (feature 1 > 29.5)
#         If (feature 2 <= 417.5)
#          Predict: 1222.247442455243
#         Else (feature 2 > 417.5)
#          Predict: 1596.6465968586388
#      Else (feature 4 > 22.5)
#       If (feature 1 <= 25.5)
#        If (feature 2 <= 266.5)
#         If (feature 3 <= 1.5)
#          Predict: 2481.1075949367087
#         Else (feature 3 > 1.5)
#          Predict: 1544.4342105263158
#        Else (feature 2 > 266.5)
#         If (feature 2 <= 287.5)
#          Predict: 6788.615384615385
#         Else (feature 2 > 287.5)
#          Predict: 2643.9310344827586
#       Else (feature 1 > 25.5)
#        If (feature 0 <= 60.5)
#         If (feature 4 <= 188.5)
#          Predict: 1614.9182692307693
#         Else (feature 4 > 188.5)
#          Predict: 1244.875789473684
#        Else (feature 0 > 60.5)
#         If (feature 3 <= 4.5)
#          Predict: 2110.970588235294
#         Else (feature 3 > 4.5)
#          Predict: 8750.25
#   Tree 5 (weight 1.0):
#     If (feature 2 <= 417.5)
#      If (feature 0 <= 54.5)
#       If (feature 0 <= 37.5)
#        If (feature 0 <= 29.5)
#         If (feature 2 <= 92.5)
#          Predict: 726.4359823399559
#         Else (feature 2 > 92.5)
#          Predict: 1026.8831706595681
#        Else (feature 0 > 29.5)
#         If (feature 1 <= 1.5)
#          Predict: 3305.6935483870966
#         Else (feature 1 > 1.5)
#          Predict: 1135.8304871330763
#       Else (feature 0 > 37.5)
#        If (feature 1 <= 21.5)
#         If (feature 3 <= 30.5)
#          Predict: 1448.794506031953
#         Else (feature 3 > 30.5)
#          Predict: 5380.0
#        Else (feature 1 > 21.5)
#         If (feature 2 <= 287.5)
#          Predict: 1063.53704837722
#         Else (feature 2 > 287.5)
#          Predict: 1607.2037470725995
#      Else (feature 0 > 54.5)
#       If (feature 2 <= 143.5)
#        If (feature 3 <= 1.5)
#         If (feature 0 <= 56.5)
#          Predict: 1471.2163265306122
#         Else (feature 0 > 56.5)
#          Predict: 2297.8363970588234
#        Else (feature 3 > 1.5)
#         If (feature 0 <= 58.5)
#          Predict: 1613.0701754385964
#         Else (feature 0 > 58.5)
#          Predict: 1956.2522202486678
#       Else (feature 2 > 143.5)
#        If (feature 2 <= 378.5)
#         If (feature 1 <= 18.5)
#          Predict: 1978.3819935691317
#         Else (feature 1 > 18.5)
#          Predict: 2601.8231780167266
#        Else (feature 2 > 378.5)
#         If (feature 4 <= 349.5)
#          Predict: 1130.8115183246073
#         Else (feature 4 > 349.5)
#          Predict: 7821.25
#     Else (feature 2 > 417.5)
#      If (feature 3 <= 11.5)
#       If (feature 5 <= 10.5)
#        If (feature 0 <= 60.5)
#         If (feature 1 <= 29.5)
#          Predict: 1481.4091332712023
#         Else (feature 1 > 29.5)
#          Predict: 1868.5304347826086
#        Else (feature 0 > 60.5)
#         If (feature 3 <= 2.5)
#          Predict: 4469.229268292683
#         Else (feature 3 > 2.5)
#          Predict: 1685.68
#       Else (feature 5 > 10.5)
#        If (feature 5 <= 13.5)
#         If (feature 1 <= 12.5)
#          Predict: 7379.705882352941
#         Else (feature 1 > 12.5)
#          Predict: 2997.6666666666665
#        Else (feature 5 > 13.5)
#         If (feature 1 <= 2.5)
#          Predict: 4987.0
#         Else (feature 1 > 2.5)
#          Predict: 653.45
#      Else (feature 3 > 11.5)
#       If (feature 0 <= 50.5)
#        If (feature 2 <= 895.5)
#         If (feature 3 <= 14.5)
#          Predict: 941.6666666666666
#         Else (feature 3 > 14.5)
#          Predict: 244.10714285714286
#        Else (feature 2 > 895.5)
#         Predict: 331.10526315789474
#       Else (feature 0 > 50.5)
#        If (feature 0 <= 58.5)
#         If (feature 2 <= 559.5)
#          Predict: 103.2
#         Else (feature 2 > 559.5)
#          Predict: 15.666666666666666
#        Else (feature 0 > 58.5)
#         If (feature 3 <= 20.5)
#          Predict: 0.0
#         Else (feature 3 > 20.5)
#          Predict: 773.0
#   Tree 6 (weight 1.0):
#     If (feature 0 <= 53.5)
#      If (feature 0 <= 30.5)
#       If (feature 1 <= 3.5)
#        If (feature 1 <= 2.5)
#         If (feature 4 <= 349.5)
#          Predict: 1045.1746031746031
#         Else (feature 4 > 349.5)
#          Predict: 6746.333333333333
#        Else (feature 1 > 2.5)
#         If (feature 3 <= 1.5)
#          Predict: 2292.7596899224804
#         Else (feature 3 > 1.5)
#          Predict: 1121.2644628099174
#       Else (feature 1 > 3.5)
#        If (feature 0 <= 29.5)
#         If (feature 5 <= 6.5)
#          Predict: 860.2664670658683
#         Else (feature 5 > 6.5)
#          Predict: 2076.5104166666665
#        Else (feature 0 > 29.5)
#         If (feature 1 <= 6.5)
#          Predict: 1475.9333333333334
#         Else (feature 1 > 6.5)
#          Predict: 1034.1362683438156
#      Else (feature 0 > 30.5)
#       If (feature 0 <= 42.5)
#        If (feature 1 <= 11.5)
#         If (feature 2 <= 153.5)
#          Predict: 960.400520639643
#         Else (feature 2 > 153.5)
#          Predict: 1158.1155714650984
#        Else (feature 1 > 11.5)
#         If (feature 2 <= 341.5)
#          Predict: 1275.423556715985
#         Else (feature 2 > 341.5)
#          Predict: 1513.944274549779
#       Else (feature 0 > 42.5)
#        If (feature 5 <= 23.5)
#         If (feature 4 <= 188.5)
#          Predict: 1468.4654457831325
#         Else (feature 4 > 188.5)
#          Predict: 1118.9267285861713
#        Else (feature 5 > 23.5)
#         If (feature 4 <= 280.5)
#          Predict: -131.625
#         Else (feature 4 > 280.5)
#          Predict: 510.75
#     Else (feature 0 > 53.5)
#      If (feature 4 <= 280.5)
#       If (feature 4 <= 27.5)
#        If (feature 4 <= -0.5)
#         If (feature 1 <= 21.5)
#          Predict: 2079.800390911312
#         Else (feature 1 > 21.5)
#          Predict: 1484.6867954911434
#        Else (feature 4 > -0.5)
#         If (feature 2 <= 92.5)
#          Predict: -74.1
#         Else (feature 2 > 92.5)
#          Predict: 505.6521739130435
#       Else (feature 4 > 27.5)
#        If (feature 4 <= 31.5)
#         If (feature 1 <= 18.5)
#          Predict: 2194.3333333333335
#         Else (feature 1 > 18.5)
#          Predict: 26254.0
#        Else (feature 4 > 31.5)
#         If (feature 1 <= 25.5)
#          Predict: 2598.5304010349287
#         Else (feature 1 > 25.5)
#          Predict: 1797.2640449438202
#      Else (feature 4 > 280.5)
#       If (feature 0 <= 56.5)
#        If (feature 5 <= 4.5)
#         If (feature 2 <= 109.5)
#          Predict: 144.10526315789474
#         Else (feature 2 > 109.5)
#          Predict: 777.542372881356
#        Else (feature 5 > 4.5)
#         If (feature 1 <= 8.5)
#          Predict: 20.0
#         Else (feature 1 > 8.5)
#          Predict: 147.42857142857142
#       Else (feature 0 > 56.5)
#        If (feature 1 <= 15.5)
#         If (feature 5 <= 6.5)
#          Predict: 995.752688172043
#         Else (feature 5 > 6.5)
#          Predict: 357.0
#        Else (feature 1 > 15.5)
#         If (feature 2 <= 895.5)
#          Predict: 2504.148936170213
#         Else (feature 2 > 895.5)
#          Predict: 7766.0
#   Tree 7 (weight 1.0):
#     If (feature 5 <= 0.5)
#      If (feature 1 <= 21.5)
#       If (feature 2 <= 475.5)
#        If (feature 1 <= 18.5)
#         If (feature 3 <= 5.5)
#          Predict: 1196.7822314766615
#         Else (feature 3 > 5.5)
#          Predict: 1380.7580760947594
#        Else (feature 1 > 18.5)
#         If (feature 3 <= 1.5)
#          Predict: 2191.0046893317704
#         Else (feature 3 > 1.5)
#          Predict: 1658.9658425504228
#       Else (feature 2 > 475.5)
#        If (feature 0 <= 60.5)
#         If (feature 1 <= 17.5)
#          Predict: 1408.0011746280345
#         Else (feature 1 > 17.5)
#          Predict: 1881.042316258352
#        Else (feature 0 > 60.5)
#         If (feature 3 <= 3.5)
#          Predict: 3910.6559139784945
#         Else (feature 3 > 3.5)
#          Predict: 1939.6666666666667
#      Else (feature 1 > 21.5)
#       If (feature 2 <= 676.5)
#        If (feature 1 <= 29.5)
#         If (feature 0 <= 54.5)
#          Predict: 912.3506960738307
#         Else (feature 0 > 54.5)
#          Predict: 1504.3429256594725
#        Else (feature 1 > 29.5)
#         If (feature 0 <= 47.5)
#          Predict: 1020.5254934210526
#         Else (feature 0 > 47.5)
#          Predict: 1997.4720616570328
#       Else (feature 2 > 676.5)
#        If (feature 1 <= 28.5)
#         If (feature 0 <= 38.5)
#          Predict: 1022.4479166666666
#         Else (feature 0 > 38.5)
#          Predict: 1667.157894736842
#        Else (feature 1 > 28.5)
#         Predict: 1851.8115942028985
#     Else (feature 5 > 0.5)
#      If (feature 1 <= 18.5)
#       If (feature 0 <= 60.5)
#        If (feature 2 <= 143.5)
#         If (feature 0 <= 51.5)
#          Predict: 967.7188552188552
#         Else (feature 0 > 51.5)
#          Predict: 1363.5017793594307
#        Else (feature 2 > 143.5)
#         If (feature 4 <= 188.5)
#          Predict: 1859.153603034134
#         Else (feature 4 > 188.5)
#          Predict: 1065.6551086453999
#       Else (feature 0 > 60.5)
#        If (feature 5 <= 12.5)
#         If (feature 1 <= 14.5)
#          Predict: 2143.6311111111113
#         Else (feature 1 > 14.5)
#          Predict: 4777.85294117647
#        Else (feature 5 > 12.5)
#         If (feature 5 <= 13.5)
#          Predict: 8304.0
#         Else (feature 5 > 13.5)
#          Predict: 2590.0
#      Else (feature 1 > 18.5)
#       If (feature 2 <= 126.5)
#        If (feature 0 <= 56.5)
#         If (feature 3 <= 2.5)
#          Predict: 1301.5576131687242
#         Else (feature 3 > 2.5)
#          Predict: 1926.8461538461538
#        Else (feature 0 > 56.5)
#         If (feature 2 <= 55.5)
#          Predict: 5833.5625
#         Else (feature 2 > 55.5)
#          Predict: 2186.4523809523807
#       Else (feature 2 > 126.5)
#        If (feature 2 <= 143.5)
#         If (feature 0 <= 25.5)
#          Predict: 12528.5
#         Else (feature 0 > 25.5)
#          Predict: 2461.442857142857
#        Else (feature 2 > 143.5)
#         If (feature 0 <= 41.5)
#          Predict: 1767.086269744836
#         Else (feature 0 > 41.5)
#          Predict: 2276.4495021337125
#   Tree 8 (weight 1.0):
#     If (feature 0 <= 50.5)
#      If (feature 0 <= 29.5)
#       If (feature 1 <= 3.5)
#        If (feature 2 <= 55.5)
#         If (feature 2 <= 42.5)
#          Predict: 450.2857142857143
#         Else (feature 2 > 42.5)
#          Predict: 4701.888888888889
#        Else (feature 2 > 55.5)
#         If (feature 1 <= 2.5)
#          Predict: 1190.0652173913043
#         Else (feature 1 > 2.5)
#          Predict: 1588.581818181818
#       Else (feature 1 > 3.5)
#        If (feature 5 <= 6.5)
#         If (feature 3 <= 16.5)
#          Predict: 899.6933701657458
#         Else (feature 3 > 16.5)
#          Predict: 1618.6078431372548
#        Else (feature 5 > 6.5)
#         If (feature 0 <= 28.5)
#          Predict: 2540.1063829787236
#         Else (feature 0 > 28.5)
#          Predict: 381.0625
#      Else (feature 0 > 29.5)
#       If (feature 1 <= 23.5)
#        If (feature 3 <= 30.5)
#         If (feature 4 <= 280.5)
#          Predict: 1366.128162185985
#         Else (feature 4 > 280.5)
#          Predict: 984.4905660377359
#        Else (feature 3 > 30.5)
#         If (feature 3 <= 31.5)
#          Predict: 27557.0
#         Else (feature 3 > 31.5)
#          Predict: 1332.2941176470588
#       Else (feature 1 > 23.5)
#        If (feature 2 <= 676.5)
#         If (feature 5 <= 2.5)
#          Predict: 958.2218655589124
#         Else (feature 5 > 2.5)
#          Predict: 1710.8720930232557
#        Else (feature 2 > 676.5)
#         If (feature 4 <= 280.5)
#          Predict: 1713.6845425867507
#         Else (feature 4 > 280.5)
#          Predict: 11008.0
#     Else (feature 0 > 50.5)
#      If (feature 0 <= 58.5)
#       If (feature 5 <= 21.5)
#        If (feature 4 <= 188.5)
#         If (feature 1 <= 3.5)
#          Predict: 2962.375
#         Else (feature 1 > 3.5)
#          Predict: 1724.2532196019401
#        Else (feature 4 > 188.5)
#         If (feature 2 <= 266.5)
#          Predict: 819.1826086956522
#         Else (feature 2 > 266.5)
#          Predict: 1719.1768292682927
#       Else (feature 5 > 21.5)
#        If (feature 5 <= 23.5)
#         Predict: 18931.0
#        Else (feature 5 > 23.5)
#         Predict: 1554.0
#      Else (feature 0 > 58.5)
#       If (feature 0 <= 60.5)
#        If (feature 1 <= 6.5)
#         If (feature 5 <= 0.5)
#          Predict: 3712.463519313305
#         Else (feature 5 > 0.5)
#          Predict: 1893.9038461538462
#        Else (feature 1 > 6.5)
#         If (feature 1 <= 21.5)
#          Predict: 2028.0103896103897
#         Else (feature 1 > 21.5)
#          Predict: 1391.1709401709402
#       Else (feature 0 > 60.5)
#        If (feature 2 <= 214.5)
#         If (feature 2 <= 92.5)
#          Predict: 2650.064516129032
#         Else (feature 2 > 92.5)
#          Predict: 2052.5454545454545
#        Else (feature 2 > 214.5)
#         If (feature 3 <= 2.5)
#          Predict: 3321.3095684803
#         Else (feature 3 > 2.5)
#          Predict: 2227.6124031007753
#   Tree 9 (weight 1.0):
#     If (feature 1 <= 1.5)
#      If (feature 4 <= 93.5)
#       If (feature 3 <= 1.5)
#        If (feature 2 <= 174.5)
#         If (feature 0 <= 60.5)
#          Predict: 876.65625
#         Else (feature 0 > 60.5)
#          Predict: 8529.0
#        Else (feature 2 > 174.5)
#         If (feature 0 <= 36.5)
#          Predict: 1207.25
#         Else (feature 0 > 36.5)
#          Predict: 3055.5897435897436
#       Else (feature 3 > 1.5)
#        If (feature 2 <= 75.5)
#         If (feature 4 <= -0.5)
#          Predict: 20616.333333333332
#         Else (feature 4 > -0.5)
#          Predict: 7541.0
#        Else (feature 2 > 75.5)
#         If (feature 4 <= -0.5)
#          Predict: 1236.4857142857143
#         Else (feature 4 > -0.5)
#          Predict: 1365.6
#      Else (feature 4 > 93.5)
#       If (feature 0 <= 60.5)
#        If (feature 3 <= 5.5)
#         If (feature 3 <= 1.5)
#          Predict: 1136.8297872340424
#         Else (feature 3 > 1.5)
#          Predict: 2034.6666666666667
#        Else (feature 3 > 5.5)
#         If (feature 2 <= 109.5)
#          Predict: 7702.0
#         Else (feature 2 > 109.5)
#          Predict: 970.0
#       Else (feature 0 > 60.5)
#        If (feature 3 <= 1.5)
#         If (feature 5 <= 2.5)
#          Predict: 965.3333333333334
#         Else (feature 5 > 2.5)
#          Predict: 54918.0
#        Else (feature 3 > 1.5)
#         If (feature 2 <= 417.5)
#          Predict: 1840.0
#         Else (feature 2 > 417.5)
#          Predict: 1413.0
#     Else (feature 1 > 1.5)
#      If (feature 2 <= 378.5)
#       If (feature 0 <= 50.5)
#        If (feature 1 <= 13.5)
#         If (feature 5 <= 0.5)
#          Predict: 989.4596756756757
#         Else (feature 5 > 0.5)
#          Predict: 1162.2254901960785
#        Else (feature 1 > 13.5)
#         If (feature 3 <= 1.5)
#          Predict: 1410.8225073075673
#         Else (feature 3 > 1.5)
#          Predict: 1223.3329406434073
#       Else (feature 0 > 50.5)
#        If (feature 0 <= 58.5)
#         If (feature 0 <= 54.5)
#          Predict: 1617.4715168153741
#         Else (feature 0 > 54.5)
#          Predict: 1862.6532351801627
#        Else (feature 0 > 58.5)
#         If (feature 1 <= 21.5)
#          Predict: 2357.6138125440452
#         Else (feature 1 > 21.5)
#          Predict: 1908.4135802469136
#      Else (feature 2 > 378.5)
#       If (feature 4 <= 33.5)
#        If (feature 1 <= 21.5)
#         If (feature 0 <= 60.5)
#          Predict: 1488.368984999026
#         Else (feature 0 > 60.5)
#          Predict: 3923.568181818182
#        Else (feature 1 > 21.5)
#         If (feature 0 <= 60.5)
#          Predict: 1128.736230110159
#         Else (feature 0 > 60.5)
#          Predict: 2739.25
#       Else (feature 4 > 33.5)
#        If (feature 4 <= 35.5)
#         If (feature 5 <= 1.5)
#          Predict: 12519.0
#         Else (feature 5 > 1.5)
#          Predict: 6495.0
#        Else (feature 4 > 35.5)
#         If (feature 1 <= 24.5)
#          Predict: 1743.9505327245054
#         Else (feature 1 > 24.5)
#          Predict: 3035.4158415841584
#   Tree 10 (weight 1.0):
#     If (feature 0 <= 54.5)
#      If (feature 2 <= 417.5)
#       If (feature 1 <= 16.5)
#        If (feature 3 <= 5.5)
#         If (feature 4 <= 280.5)
#          Predict: 1121.9488178025035
#         Else (feature 4 > 280.5)
#          Predict: 865.0502344273275
#        Else (feature 3 > 5.5)
#         If (feature 0 <= 31.5)
#          Predict: 1740.7796610169491
#         Else (feature 0 > 31.5)
#          Predict: 1183.775672981057
#       Else (feature 1 > 16.5)
#        If (feature 4 <= 31.5)
#         If (feature 3 <= 1.5)
#          Predict: 1460.92
#         Else (feature 3 > 1.5)
#          Predict: 1194.7170435153585
#        Else (feature 4 > 31.5)
#         If (feature 1 <= 18.5)
#          Predict: 1280.4541723666212
#         Else (feature 1 > 18.5)
#          Predict: 1847.8396572827417
#      Else (feature 2 > 417.5)
#       If (feature 3 <= 8.5)
#        If (feature 4 <= 33.5)
#         If (feature 3 <= 5.5)
#          Predict: 1414.6486652977412
#         Else (feature 3 > 5.5)
#          Predict: 1153.8319672131147
#        Else (feature 4 > 33.5)
#         If (feature 4 <= 35.5)
#          Predict: 12519.0
#         Else (feature 4 > 35.5)
#          Predict: 1647.7097361237488
#       Else (feature 3 > 8.5)
#        If (feature 3 <= 9.5)
#         If (feature 5 <= 0.5)
#          Predict: 5098.558139534884
#         Else (feature 5 > 0.5)
#          Predict: 560.0
#        Else (feature 3 > 9.5)
#         If (feature 0 <= 27.5)
#          Predict: 2698.0
#         Else (feature 0 > 27.5)
#          Predict: 1085.404761904762
#     Else (feature 0 > 54.5)
#      If (feature 1 <= 1.5)
#       If (feature 5 <= 2.5)
#        If (feature 4 <= -0.5)
#         If (feature 0 <= 56.5)
#          Predict: 7523.833333333333
#         Else (feature 0 > 56.5)
#          Predict: 2780.516129032258
#        Else (feature 4 > -0.5)
#         If (feature 0 <= 56.5)
#          Predict: 2076.0
#         Else (feature 0 > 56.5)
#          Predict: 1258.0
#       Else (feature 5 > 2.5)
#        If (feature 4 <= 163.5)
#         If (feature 5 <= 3.5)
#          Predict: 81204.0
#         Else (feature 5 > 3.5)
#          Predict: 2718.5
#        Else (feature 4 > 163.5)
#         If (feature 0 <= 58.5)
#          Predict: 2986.0
#         Else (feature 0 > 58.5)
#          Predict: 1085.857142857143
#      Else (feature 1 > 1.5)
#       If (feature 2 <= 163.5)
#        If (feature 0 <= 56.5)
#         If (feature 1 <= 22.5)
#          Predict: 1586.4709897610921
#         Else (feature 1 > 22.5)
#          Predict: 1080.8431372549019
#        Else (feature 0 > 56.5)
#         If (feature 2 <= 118.5)
#          Predict: 2072.175687666371
#         Else (feature 2 > 118.5)
#          Predict: 1728.8082191780823
#       Else (feature 2 > 163.5)
#        If (feature 3 <= 3.5)
#         If (feature 4 <= 93.5)
#          Predict: 2198.5506976744186
#         Else (feature 4 > 93.5)
#          Predict: 2487.09626719057
#        Else (feature 3 > 3.5)
#         If (feature 5 <= 3.5)
#          Predict: 1465.3549695740364
#         Else (feature 5 > 3.5)
#          Predict: 4174.793103448276
#   Tree 11 (weight 1.0):
#     If (feature 4 <= 280.5)
#      If (feature 0 <= 53.5)
#       If (feature 1 <= 21.5)
#        If (feature 5 <= 0.5)
#         If (feature 0 <= 29.5)
#          Predict: 856.7277345072807
#         Else (feature 0 > 29.5)
#          Predict: 1332.1197590125391
#        Else (feature 5 > 0.5)
#         If (feature 2 <= 55.5)
#          Predict: 2035.1004566210045
#         Else (feature 2 > 55.5)
#          Predict: 1624.1218243036426
#       Else (feature 1 > 21.5)
#        If (feature 4 <= 35.5)
#         If (feature 2 <= 312.5)
#          Predict: 991.257393715342
#         Else (feature 2 > 312.5)
#          Predict: 1186.3647416413373
#        Else (feature 4 > 35.5)
#         If (feature 3 <= 3.5)
#          Predict: 1439.8994974874372
#         Else (feature 3 > 3.5)
#          Predict: 2489.259259259259
#      Else (feature 0 > 53.5)
#       If (feature 5 <= 0.5)
#        If (feature 1 <= 21.5)
#         If (feature 2 <= 75.5)
#          Predict: 2802.0973913043476
#         Else (feature 2 > 75.5)
#          Predict: 2061.2076923076925
#        Else (feature 1 > 21.5)
#         If (feature 2 <= 186.5)
#          Predict: 1263.6827195467422
#         Else (feature 2 > 186.5)
#          Predict: 1632.3846153846155
#       Else (feature 5 > 0.5)
#        If (feature 1 <= 1.5)
#         If (feature 2 <= 341.5)
#          Predict: 2539.0555555555557
#         Else (feature 2 > 341.5)
#          Predict: 9466.8
#        Else (feature 1 > 1.5)
#         If (feature 5 <= 10.5)
#          Predict: 2373.2902240325866
#         Else (feature 5 > 10.5)
#          Predict: 3836.5333333333333
#     Else (feature 4 > 280.5)
#      If (feature 4 <= 349.5)
#       If (feature 0 <= 39.5)
#        If (feature 3 <= 4.5)
#         If (feature 2 <= 559.5)
#          Predict: 952.8515283842795
#         Else (feature 2 > 559.5)
#          Predict: 1564.3720930232557
#        Else (feature 3 > 4.5)
#         If (feature 2 <= 66.5)
#          Predict: 478.7352941176471
#         Else (feature 2 > 66.5)
#          Predict: 902.8181818181819
#       Else (feature 0 > 39.5)
#        If (feature 0 <= 54.5)
#         If (feature 3 <= 3.5)
#          Predict: 695.0206896551724
#         Else (feature 3 > 3.5)
#          Predict: 518.0886075949367
#        Else (feature 0 > 54.5)
#         If (feature 5 <= 12.5)
#          Predict: 1225.3846153846155
#         Else (feature 5 > 12.5)
#          Predict: 5253.0
#      Else (feature 4 > 349.5)
#       If (feature 0 <= 45.5)
#        If (feature 0 <= 42.5)
#         If (feature 1 <= 22.5)
#          Predict: 905.1287703016242
#         Else (feature 1 > 22.5)
#          Predict: 1835.7611940298507
#        Else (feature 0 > 42.5)
#         If (feature 1 <= 15.5)
#          Predict: 411.95402298850576
#         Else (feature 1 > 15.5)
#          Predict: 1062.0
#       Else (feature 0 > 45.5)
#        If (feature 2 <= 75.5)
#         If (feature 1 <= 15.5)
#          Predict: 517.1818181818181
#         Else (feature 1 > 15.5)
#          Predict: 1484.8
#        Else (feature 2 > 75.5)
#         If (feature 1 <= 22.5)
#          Predict: 1429.4163424124513
#         Else (feature 1 > 22.5)
#          Predict: 3057.7179487179487
#   Tree 12 (weight 1.0):
#     If (feature 0 <= 54.5)
#      If (feature 5 <= 0.5)
#       If (feature 1 <= 21.5)
#        If (feature 1 <= 17.5)
#         If (feature 1 <= 3.5)
#          Predict: 1363.5294778214486
#         Else (feature 1 > 3.5)
#          Predict: 1098.7900230532787
#        Else (feature 1 > 17.5)
#         If (feature 0 <= 29.5)
#          Predict: 825.9912587412588
#         Else (feature 0 > 29.5)
#          Predict: 1806.634542964738
#       Else (feature 1 > 21.5)
#        If (feature 3 <= 7.5)
#         If (feature 2 <= 135.5)
#          Predict: 879.1885160843999
#         Else (feature 2 > 135.5)
#          Predict: 1053.4077712289893
#        Else (feature 3 > 7.5)
#         If (feature 2 <= 559.5)
#          Predict: 1138.2839116719242
#         Else (feature 2 > 559.5)
#          Predict: 2987.5405405405404
#      Else (feature 5 > 0.5)
#       If (feature 4 <= 188.5)
#        If (feature 1 <= 9.5)
#         If (feature 0 <= 30.5)
#          Predict: 1176.3641304347825
#         Else (feature 0 > 30.5)
#          Predict: 1547.7259923175416
#        Else (feature 1 > 9.5)
#         If (feature 2 <= 559.5)
#          Predict: 2189.5260416666665
#         Else (feature 2 > 559.5)
#          Predict: 1492.6187845303868
#       Else (feature 4 > 188.5)
#        If (feature 2 <= 895.5)
#         If (feature 1 <= 18.5)
#          Predict: 876.8202134756505
#         Else (feature 1 > 18.5)
#          Predict: 1417.9777486910996
#        Else (feature 2 > 895.5)
#         If (feature 4 <= 349.5)
#          Predict: 1399.103448275862
#         Else (feature 4 > 349.5)
#          Predict: 3422.53125
#     Else (feature 0 > 54.5)
#      If (feature 4 <= 22.5)
#       If (feature 1 <= 21.5)
#        If (feature 0 <= 58.5)
#         If (feature 3 <= 17.5)
#          Predict: 1882.606222654351
#         Else (feature 3 > 17.5)
#          Predict: 5453.166666666667
#        Else (feature 0 > 58.5)
#         If (feature 2 <= 66.5)
#          Predict: 3285.7806451612905
#         Else (feature 2 > 66.5)
#          Predict: 2304.363981762918
#       Else (feature 1 > 21.5)
#        If (feature 0 <= 60.5)
#         If (feature 1 <= 24.5)
#          Predict: 655.9276315789474
#         Else (feature 1 > 24.5)
#          Predict: 1488.1217063989961
#        Else (feature 0 > 60.5)
#         Predict: 2430.3267326732675
#      Else (feature 4 > 22.5)
#       If (feature 1 <= 15.5)
#        If (feature 0 <= 60.5)
#         If (feature 5 <= 1.5)
#          Predict: 2130.242424242424
#         Else (feature 5 > 1.5)
#          Predict: 1169.81512605042
#        Else (feature 0 > 60.5)
#         If (feature 4 <= 188.5)
#          Predict: 2308.1279069767443
#         Else (feature 4 > 188.5)
#          Predict: 4097.477272727273
#       Else (feature 1 > 15.5)
#        If (feature 1 <= 28.5)
#         If (feature 3 <= 4.5)
#          Predict: 3234.8649350649353
#         Else (feature 3 > 4.5)
#          Predict: 1641.8148148148148
#        Else (feature 1 > 28.5)
#         If (feature 2 <= 287.5)
#          Predict: 1087.9148936170213
#         Else (feature 2 > 287.5)
#          Predict: 3466.9166666666665
#   Tree 13 (weight 1.0):
#     If (feature 0 <= 54.5)
#      If (feature 1 <= 21.5)
#       If (feature 1 <= 17.5)
#        If (feature 1 <= 4.5)
#         If (feature 2 <= 378.5)
#          Predict: 1262.395593220339
#         Else (feature 2 > 378.5)
#          Predict: 1661.3268656716418
#        Else (feature 1 > 4.5)
#         If (feature 5 <= 0.5)
#          Predict: 1072.0259233926129
#         Else (feature 5 > 0.5)
#          Predict: 1335.8421615837347
#       Else (feature 1 > 17.5)
#        If (feature 3 <= 3.5)
#         If (feature 3 <= 1.5)
#          Predict: 2004.2610020311442
#         Else (feature 3 > 1.5)
#          Predict: 1777.3504300732718
#        Else (feature 3 > 3.5)
#         If (feature 2 <= 118.5)
#          Predict: 1257.1461988304093
#         Else (feature 2 > 118.5)
#          Predict: 1553.220376522702
#      Else (feature 1 > 21.5)
#       If (feature 1 <= 29.5)
#        If (feature 4 <= 28.5)
#         If (feature 2 <= 676.5)
#          Predict: 889.9461050023231
#         Else (feature 2 > 676.5)
#          Predict: 1352.4763157894736
#        Else (feature 4 > 28.5)
#         If (feature 1 <= 27.5)
#          Predict: 1997.9430894308944
#         Else (feature 1 > 27.5)
#          Predict: 1013.8219895287958
#       Else (feature 1 > 29.5)
#        If (feature 0 <= 44.5)
#         If (feature 2 <= 163.5)
#          Predict: 938.6618075801749
#         Else (feature 2 > 163.5)
#          Predict: 1320.1524725274726
#        Else (feature 0 > 44.5)
#         If (feature 0 <= 51.5)
#          Predict: 2048.3882063882065
#         Else (feature 0 > 51.5)
#          Predict: 1388.4329268292684
#     Else (feature 0 > 54.5)
#      If (feature 0 <= 60.5)
#       If (feature 3 <= 7.5)
#        If (feature 5 <= 3.5)
#         If (feature 2 <= 143.5)
#          Predict: 1723.0244200244201
#         Else (feature 2 > 143.5)
#          Predict: 2044.8098705501618
#        Else (feature 5 > 3.5)
#         If (feature 0 <= 58.5)
#          Predict: 2778.1327433628317
#         Else (feature 0 > 58.5)
#          Predict: 1708.6301369863013
#       Else (feature 3 > 7.5)
#        If (feature 3 <= 12.5)
#         If (feature 2 <= 42.5)
#          Predict: 929.2692307692307
#         Else (feature 2 > 42.5)
#          Predict: 3709.84496124031
#        Else (feature 3 > 12.5)
#         If (feature 2 <= 55.5)
#          Predict: 548.3846153846154
#         Else (feature 2 > 55.5)
#          Predict: 1622.1142857142856
#      Else (feature 0 > 60.5)
#       If (feature 2 <= 246.5)
#        If (feature 3 <= 2.5)
#         If (feature 2 <= 92.5)
#          Predict: 2407.909090909091
#         Else (feature 2 > 92.5)
#          Predict: 1857.8994565217392
#        Else (feature 3 > 2.5)
#         If (feature 1 <= 11.5)
#          Predict: 3434.1153846153848
#         Else (feature 1 > 11.5)
#          Predict: 2053.5353535353534
#       Else (feature 2 > 246.5)
#        If (feature 1 <= 29.5)
#         If (feature 1 <= 5.5)
#          Predict: 4421.252525252526
#         Else (feature 1 > 5.5)
#          Predict: 2666.6147186147186
#        Else (feature 1 > 29.5)
#         If (feature 5 <= 3.5)
#          Predict: 3823.9285714285716
#         Else (feature 5 > 3.5)
#          Predict: 29080.0
#   Tree 14 (weight 1.0):
#     If (feature 0 <= 54.5)
#      If (feature 4 <= 280.5)
#       If (feature 0 <= 30.5)
#        If (feature 4 <= 25.5)
#         If (feature 1 <= 3.5)
#          Predict: 1475.518134715026
#         Else (feature 1 > 3.5)
#          Predict: 900.9423507462686
#        Else (feature 4 > 25.5)
#         If (feature 2 <= 895.5)
#          Predict: 1351.3970390309555
#         Else (feature 2 > 895.5)
#          Predict: 2842.181818181818
#       Else (feature 0 > 30.5)
#        If (feature 4 <= 31.5)
#         If (feature 1 <= 21.5)
#          Predict: 1388.682939053729
#         Else (feature 1 > 21.5)
#          Predict: 1084.9927693420102
#        Else (feature 4 > 31.5)
#         If (feature 2 <= 42.5)
#          Predict: 2810.3161290322582
#         Else (feature 2 > 42.5)
#          Predict: 1635.425343249428
#      Else (feature 4 > 280.5)
#       If (feature 2 <= 143.5)
#        If (feature 1 <= 18.5)
#         If (feature 2 <= 20.5)
#          Predict: 483.7047619047619
#         Else (feature 2 > 20.5)
#          Predict: 753.9155313351498
#        Else (feature 1 > 18.5)
#         If (feature 0 <= 34.5)
#          Predict: 1873.8809523809523
#         Else (feature 0 > 34.5)
#          Predict: 686.2948717948718
#       Else (feature 2 > 143.5)
#        If (feature 1 <= 2.5)
#         If (feature 2 <= 163.5)
#          Predict: 11652.166666666666
#         Else (feature 2 > 163.5)
#          Predict: 2144.0408163265306
#        Else (feature 1 > 2.5)
#         If (feature 2 <= 895.5)
#          Predict: 973.4142011834319
#         Else (feature 2 > 895.5)
#          Predict: 1454.0
#     Else (feature 0 > 54.5)
#      If (feature 0 <= 58.5)
#       If (feature 1 <= 25.5)
#        If (feature 4 <= 9.5)
#         If (feature 2 <= 163.5)
#          Predict: 1673.174002047083
#         Else (feature 2 > 163.5)
#          Predict: 1948.2249346120313
#        Else (feature 4 > 9.5)
#         If (feature 3 <= 8.5)
#          Predict: 2481.7416879795396
#         Else (feature 3 > 8.5)
#          Predict: 5769.4
#       Else (feature 1 > 25.5)
#        If (feature 4 <= 349.5)
#         If (feature 5 <= 6.5)
#          Predict: 1472.7971014492753
#         Else (feature 5 > 6.5)
#          Predict: 2583.8333333333335
#        Else (feature 4 > 349.5)
#         Predict: 7024.5
#      Else (feature 0 > 58.5)
#       If (feature 5 <= 16.5)
#        If (feature 3 <= 4.5)
#         If (feature 2 <= 55.5)
#          Predict: 4388.493827160494
#         Else (feature 2 > 55.5)
#          Predict: 2131.5430201931517
#        Else (feature 3 > 4.5)
#         If (feature 2 <= 143.5)
#          Predict: 2059.6463414634145
#         Else (feature 2 > 143.5)
#          Predict: 4691.829629629629
#       Else (feature 5 > 16.5)
#        Predict: 10776.0
#   Tree 15 (weight 1.0):
#     If (feature 0 <= 54.5)
#      If (feature 0 <= 28.5)
#       If (feature 4 <= 27.5)
#        If (feature 1 <= 3.5)
#         If (feature 4 <= 22.5)
#          Predict: 1700.7318181818182
#         Else (feature 4 > 22.5)
#          Predict: 96.0
#        Else (feature 1 > 3.5)
#         If (feature 1 <= 26.5)
#          Predict: 705.8115758343895
#         Else (feature 1 > 26.5)
#          Predict: 1039.8797564687975
#       Else (feature 4 > 27.5)
#        If (feature 5 <= 12.5)
#         If (feature 3 <= 4.5)
#          Predict: 1003.6413902053713
#         Else (feature 3 > 4.5)
#          Predict: 1637.25
#        Else (feature 5 > 12.5)
#         If (feature 0 <= 27.5)
#          Predict: 4108.333333333333
#         Else (feature 0 > 27.5)
#          Predict: 8476.6
#      Else (feature 0 > 28.5)
#       If (feature 1 <= 13.5)
#        If (feature 2 <= 559.5)
#         If (feature 1 <= 4.5)
#          Predict: 1305.1213556851312
#         Else (feature 1 > 4.5)
#          Predict: 1070.552790650816
#        Else (feature 2 > 559.5)
#         If (feature 0 <= 30.5)
#          Predict: 1780.5106382978724
#         Else (feature 0 > 30.5)
#          Predict: 1386.5012427506215
#       Else (feature 1 > 13.5)
#        If (feature 4 <= 33.5)
#         If (feature 0 <= 47.5)
#          Predict: 1266.540350877193
#         Else (feature 0 > 47.5)
#          Predict: 1603.8465143526655
#        Else (feature 4 > 33.5)
#         If (feature 4 <= 280.5)
#          Predict: 1966.0236501561803
#         Else (feature 4 > 280.5)
#          Predict: 1197.9044401544402
#     Else (feature 0 > 54.5)
#      If (feature 0 <= 60.5)
#       If (feature 4 <= 188.5)
#        If (feature 0 <= 58.5)
#         If (feature 4 <= 27.5)
#          Predict: 1928.9042512447338
#         Else (feature 4 > 27.5)
#          Predict: 2821.772093023256
#        Else (feature 0 > 58.5)
#         If (feature 3 <= 1.5)
#          Predict: 2740.255319148936
#         Else (feature 3 > 1.5)
#          Predict: 2162.0231362467866
#       Else (feature 4 > 188.5)
#        If (feature 5 <= 12.5)
#         If (feature 1 <= 18.5)
#          Predict: 1223.642857142857
#         Else (feature 1 > 18.5)
#          Predict: 2270.9444444444443
#        Else (feature 5 > 12.5)
#         If (feature 2 <= 20.5)
#          Predict: 1554.0
#         Else (feature 2 > 20.5)
#          Predict: 5462.6
#      Else (feature 0 > 60.5)
#       If (feature 5 <= 1.5)
#        If (feature 2 <= 475.5)
#         If (feature 1 <= 10.5)
#          Predict: 2436.6315789473683
#         Else (feature 1 > 10.5)
#          Predict: 1901.4970760233919
#        Else (feature 2 > 475.5)
#         If (feature 4 <= -0.5)
#          Predict: 4115.565891472868
#         Else (feature 4 > -0.5)
#          Predict: 1477.2553191489362
#       Else (feature 5 > 1.5)
#        If (feature 4 <= 280.5)
#         If (feature 1 <= 1.5)
#          Predict: 10710.388888888889
#         Else (feature 1 > 1.5)
#          Predict: 2777.6382978723404
#        Else (feature 4 > 280.5)
#         If (feature 2 <= 676.5)
#          Predict: 3191.625
#         Else (feature 2 > 676.5)
#          Predict: 41345.0
#   Tree 16 (weight 1.0):
#     If (feature 4 <= 28.5)
#      If (feature 0 <= 51.5)
#       If (feature 0 <= 33.5)
#        If (feature 1 <= 16.5)
#         If (feature 3 <= 5.5)
#          Predict: 868.7346050176238
#         Else (feature 3 > 5.5)
#          Predict: 1166.5225806451613
#        Else (feature 1 > 16.5)
#         If (feature 3 <= 1.5)
#          Predict: 1332.5799200799202
#         Else (feature 3 > 1.5)
#          Predict: 1001.466362599772
#       Else (feature 0 > 33.5)
#        If (feature 2 <= 895.5)
#         If (feature 3 <= 30.5)
#          Predict: 1250.3153263001643
#         Else (feature 3 > 30.5)
#          Predict: 5802.538461538462
#        Else (feature 2 > 895.5)
#         If (feature 1 <= 15.5)
#          Predict: 1405.9783950617284
#         Else (feature 1 > 15.5)
#          Predict: 2290.6534954407293
#      Else (feature 0 > 51.5)
#       If (feature 2 <= 186.5)
#        If (feature 1 <= 21.5)
#         If (feature 4 <= -0.5)
#          Predict: 1900.2250384024578
#         Else (feature 4 > -0.5)
#          Predict: 457.5
#        Else (feature 1 > 21.5)
#         If (feature 1 <= 30.5)
#          Predict: 1100.4838373305527
#         Else (feature 1 > 30.5)
#          Predict: 2885.5616438356165
#       Else (feature 2 > 186.5)
#        If (feature 3 <= 2.5)
#         If (feature 1 <= 7.5)
#          Predict: 2746.151202749141
#         Else (feature 1 > 7.5)
#          Predict: 1920.9405548216644
#        Else (feature 3 > 2.5)
#         If (feature 3 <= 15.5)
#          Predict: 1490.342737722048
#         Else (feature 3 > 15.5)
#          Predict: 2651.3809523809523
#     Else (feature 4 > 28.5)
#      If (feature 0 <= 60.5)
#       If (feature 2 <= 135.5)
#        If (feature 1 <= 18.5)
#         If (feature 2 <= 84.5)
#          Predict: 1214.9942594718714
#         Else (feature 2 > 84.5)
#          Predict: 1026.3684807256236
#        Else (feature 1 > 18.5)
#         If (feature 1 <= 23.5)
#          Predict: 2265.386091127098
#         Else (feature 1 > 23.5)
#          Predict: 1241.5993690851735
#       Else (feature 2 > 135.5)
#        If (feature 4 <= 188.5)
#         If (feature 2 <= 143.5)
#          Predict: 3043.8282828282827
#         Else (feature 2 > 143.5)
#          Predict: 1918.2845528455284
#        Else (feature 4 > 188.5)
#         If (feature 0 <= 37.5)
#          Predict: 1159.530303030303
#         Else (feature 0 > 37.5)
#          Predict: 1460.02238267148
#      Else (feature 0 > 60.5)
#       If (feature 1 <= 1.5)
#        If (feature 5 <= 2.5)
#         If (feature 5 <= 1.5)
#          Predict: 132.0
#         Else (feature 5 > 1.5)
#          Predict: 1465.6666666666667
#        Else (feature 5 > 2.5)
#         If (feature 2 <= 417.5)
#          Predict: 41522.0
#         Else (feature 2 > 417.5)
#          Predict: 1815.5
#       Else (feature 1 > 1.5)
#        If (feature 2 <= 153.5)
#         If (feature 2 <= 84.5)
#          Predict: 3937.4761904761904
#         Else (feature 2 > 84.5)
#          Predict: 1684.5052631578947
#        Else (feature 2 > 153.5)
#         If (feature 1 <= 29.5)
#          Predict: 2809.098639455782
#         Else (feature 1 > 29.5)
#          Predict: 8709.111111111111
#   Tree 17 (weight 1.0):
#     If (feature 4 <= 280.5)
#      If (feature 4 <= 33.5)
#       If (feature 1 <= 21.5)
#        If (feature 2 <= 417.5)
#         If (feature 0 <= 42.5)
#          Predict: 1138.1332737030411
#         Else (feature 0 > 42.5)
#          Predict: 1715.9526477116583
#        Else (feature 2 > 417.5)
#         If (feature 2 <= 676.5)
#          Predict: 1654.107338444688
#         Else (feature 2 > 676.5)
#          Predict: 1405.0822351080653
#       Else (feature 1 > 21.5)
#        If (feature 1 <= 28.5)
#         If (feature 0 <= 60.5)
#          Predict: 961.9109653233364
#         Else (feature 0 > 60.5)
#          Predict: 2165.3358208955224
#        Else (feature 1 > 28.5)
#         If (feature 0 <= 40.5)
#          Predict: 999.4807121661721
#         Else (feature 0 > 40.5)
#          Predict: 1638.162023877203
#      Else (feature 4 > 33.5)
#       If (feature 2 <= 126.5)
#        If (feature 0 <= 32.5)
#         If (feature 3 <= 6.5)
#          Predict: 1124.56346749226
#         Else (feature 3 > 6.5)
#          Predict: 138.07692307692307
#        Else (feature 0 > 32.5)
#         If (feature 1 <= 1.5)
#          Predict: 3272.7083333333335
#         Else (feature 1 > 1.5)
#          Predict: 1643.659388646288
#       Else (feature 2 > 126.5)
#        If (feature 0 <= 54.5)
#         If (feature 4 <= 35.5)
#          Predict: 10912.666666666666
#         Else (feature 4 > 35.5)
#          Predict: 1742.7230384495156
#        Else (feature 0 > 54.5)
#         If (feature 2 <= 475.5)
#          Predict: 3210.4736842105262
#         Else (feature 2 > 475.5)
#          Predict: 2429.2824427480914
#     Else (feature 4 > 280.5)
#      If (feature 1 <= 2.5)
#       If (feature 0 <= 32.5)
#        If (feature 5 <= 2.5)
#         If (feature 2 <= 559.5)
#          Predict: 1571.5833333333333
#         Else (feature 2 > 559.5)
#          Predict: 12569.0
#        Else (feature 5 > 2.5)
#         Predict: 12956.0
#       Else (feature 0 > 32.5)
#        If (feature 0 <= 45.5)
#         If (feature 2 <= 559.5)
#          Predict: 1250.8
#         Else (feature 2 > 559.5)
#          Predict: 3251.75
#        Else (feature 0 > 45.5)
#         If (feature 2 <= 174.5)
#          Predict: 514.5
#         Else (feature 2 > 174.5)
#          Predict: 3772.090909090909
#      Else (feature 1 > 2.5)
#       If (feature 0 <= 51.5)
#        If (feature 1 <= 22.5)
#         If (feature 1 <= 8.5)
#          Predict: 679.9128978224455
#         Else (feature 1 > 8.5)
#          Predict: 882.0761511216057
#        Else (feature 1 > 22.5)
#         If (feature 5 <= 4.5)
#          Predict: 1681.2093023255813
#         Else (feature 5 > 4.5)
#          Predict: 1101.0
#       Else (feature 0 > 51.5)
#        If (feature 0 <= 60.5)
#         If (feature 2 <= 214.5)
#          Predict: 887.4671052631579
#         Else (feature 2 > 214.5)
#          Predict: 2292.084745762712
#        Else (feature 0 > 60.5)
#         If (feature 2 <= 153.5)
#          Predict: 365.75
#         Else (feature 2 > 153.5)
#          Predict: 2970.3636363636365
#   Tree 18 (weight 1.0):
#     If (feature 0 <= 50.5)
#      If (feature 1 <= 17.5)
#       If (feature 0 <= 35.5)
#        If (feature 5 <= 1.5)
#         If (feature 3 <= 8.5)
#          Predict: 943.9201130233753
#         Else (feature 3 > 8.5)
#          Predict: 507.0533980582524
#        Else (feature 5 > 1.5)
#         If (feature 3 <= 1.5)
#          Predict: 1281.6897637795275
#         Else (feature 3 > 1.5)
#          Predict: 1041.6490765171504
#       Else (feature 0 > 35.5)
#        If (feature 0 <= 47.5)
#         If (feature 5 <= 9.5)
#          Predict: 1186.0201415351116
#         Else (feature 5 > 9.5)
#          Predict: 1777.439024390244
#        Else (feature 0 > 47.5)
#         If (feature 4 <= 188.5)
#          Predict: 1446.1423948220065
#         Else (feature 4 > 188.5)
#          Predict: 1081.9608938547485
#      Else (feature 1 > 17.5)
#       If (feature 1 <= 21.5)
#        If (feature 3 <= 1.5)
#         If (feature 1 <= 19.5)
#          Predict: 1736.0245298446443
#         Else (feature 1 > 19.5)
#          Predict: 2196.2414715719065
#        Else (feature 3 > 1.5)
#         If (feature 3 <= 30.5)
#          Predict: 1488.3021502992685
#         Else (feature 3 > 30.5)
#          Predict: 9277.0
#       Else (feature 1 > 21.5)
#        If (feature 5 <= 0.5)
#         If (feature 3 <= 16.5)
#          Predict: 1026.010505319149
#         Else (feature 3 > 16.5)
#          Predict: 596.1100917431193
#        Else (feature 5 > 0.5)
#         If (feature 2 <= 126.5)
#          Predict: 1149.362126245847
#         Else (feature 2 > 126.5)
#          Predict: 1928.0789115646257
#     Else (feature 0 > 50.5)
#      If (feature 1 <= 3.5)
#       If (feature 3 <= 2.5)
#        If (feature 1 <= 2.5)
#         If (feature 0 <= 60.5)
#          Predict: 1541.6288659793815
#         Else (feature 0 > 60.5)
#          Predict: 5592.826086956522
#        Else (feature 1 > 2.5)
#         If (feature 2 <= 118.5)
#          Predict: 13625.347826086956
#         Else (feature 2 > 118.5)
#          Predict: 1883.204918032787
#       Else (feature 3 > 2.5)
#        If (feature 4 <= -0.5)
#         Predict: 1620.0309278350514
#        Else (feature 4 > -0.5)
#         If (feature 1 <= 1.5)
#          Predict: 3523.0
#         Else (feature 1 > 1.5)
#          Predict: 553.2162162162163
#      Else (feature 1 > 3.5)
#       If (feature 4 <= 22.5)
#        If (feature 0 <= 54.5)
#         If (feature 1 <= 21.5)
#          Predict: 1646.409392789374
#         Else (feature 1 > 21.5)
#          Predict: 1245.59012345679
#        Else (feature 0 > 54.5)
#         If (feature 0 <= 58.5)
#          Predict: 1789.0852803738317
#         Else (feature 0 > 58.5)
#          Predict: 2008.0685008422236
#       Else (feature 4 > 22.5)
#        If (feature 1 <= 17.5)
#         If (feature 0 <= 60.5)
#          Predict: 1645.305057096248
#         Else (feature 0 > 60.5)
#          Predict: 2472.8658536585367
#        Else (feature 1 > 17.5)
#         If (feature 0 <= 60.5)
#          Predict: 2130.4942791762014
#         Else (feature 0 > 60.5)
#          Predict: 3393.3
#   Tree 19 (weight 1.0):
#     If (feature 2 <= 229.5)
#      If (feature 0 <= 50.5)
#       If (feature 3 <= 2.5)
#        If (feature 5 <= 0.5)
#         If (feature 1 <= 1.5)
#          Predict: 2885.878048780488
#         Else (feature 1 > 1.5)
#          Predict: 1173.786122967941
#        Else (feature 5 > 0.5)
#         If (feature 3 <= 1.5)
#          Predict: 1442.5583333333334
#         Else (feature 3 > 1.5)
#          Predict: 1193.0925196850394
#       Else (feature 3 > 2.5)
#        If (feature 4 <= 33.5)
#         If (feature 0 <= 42.5)
#          Predict: 971.5473957293954
#         Else (feature 0 > 42.5)
#          Predict: 1307.076760190577
#        Else (feature 4 > 33.5)
#         If (feature 2 <= 20.5)
#          Predict: 1858.7727272727273
#         Else (feature 2 > 20.5)
#          Predict: 1310.8301886792453
#      Else (feature 0 > 50.5)
#       If (feature 2 <= 20.5)
#        If (feature 4 <= 280.5)
#         If (feature 4 <= 12.5)
#          Predict: 1263.6903225806452
#         Else (feature 4 > 12.5)
#          Predict: 2448.133333333333
#        Else (feature 4 > 280.5)
#         If (feature 3 <= 1.5)
#          Predict: 360.6666666666667
#         Else (feature 3 > 1.5)
#          Predict: 112.22222222222223
#       Else (feature 2 > 20.5)
#        If (feature 0 <= 58.5)
#         If (feature 1 <= 21.5)
#          Predict: 1915.6548007838014
#         Else (feature 1 > 21.5)
#          Predict: 1165.2703984819734
#        Else (feature 0 > 58.5)
#         If (feature 2 <= 66.5)
#          Predict: 3586.0529411764705
#         Else (feature 2 > 66.5)
#          Predict: 2004.5843828715365
#     Else (feature 2 > 229.5)
#      If (feature 1 <= 17.5)
#       If (feature 0 <= 60.5)
#        If (feature 3 <= 8.5)
#         If (feature 2 <= 417.5)
#          Predict: 1151.7267002518893
#         Else (feature 2 > 417.5)
#          Predict: 1368.5996559351192
#        Else (feature 3 > 8.5)
#         If (feature 3 <= 9.5)
#          Predict: 4105.424242424242
#         Else (feature 3 > 9.5)
#          Predict: 1431.5263157894738
#       Else (feature 0 > 60.5)
#        If (feature 2 <= 378.5)
#         If (feature 1 <= 3.5)
#          Predict: 1368.361111111111
#         Else (feature 1 > 3.5)
#          Predict: 2810.071942446043
#        Else (feature 2 > 378.5)
#         If (feature 4 <= 188.5)
#          Predict: 3612.8653846153848
#         Else (feature 4 > 188.5)
#          Predict: 10578.666666666666
#      Else (feature 1 > 17.5)
#       If (feature 3 <= 3.5)
#        If (feature 4 <= 93.5)
#         If (feature 0 <= 29.5)
#          Predict: 1093.735368956743
#         Else (feature 0 > 29.5)
#          Predict: 1747.8654456654456
#        Else (feature 4 > 93.5)
#         If (feature 0 <= 56.5)
#          Predict: 1998.84496124031
#         Else (feature 0 > 56.5)
#          Predict: 3336.84126984127
#       Else (feature 3 > 3.5)
#        If (feature 5 <= 0.5)
#         If (feature 0 <= 29.5)
#          Predict: 735.0940170940171
#         Else (feature 0 > 29.5)
#          Predict: 1316.1597859327217
#        Else (feature 5 > 0.5)
#         If (feature 0 <= 60.5)
#          Predict: 2016.7808219178082
#         Else (feature 0 > 60.5)
#          Predict: 5980.333333333333

# %% [markdown]
# # Gradient boosting

# %%
from pyspark.ml.classification import GBTClassifier

clf = GBTClassifier(featuresCol='features', labelCol='y')
clf_model = clf.fit(binary_df)
print(clf_model.featureImportances)
print(clf_model.toDebugString)

# %%
from pyspark.ml.regression import GBTRegressor

reg = GBTRegressor(featuresCol='features', labelCol='balance')
reg_model = reg.fit(continuous_df)
print(reg_model.featureImportances)
print(reg_model.toDebugString)

# %% [markdown]
# # Support vector machines

# %%
from pyspark.ml.classification import LinearSVC
np.set_printoptions(precision=3, suppress=True)
clf = LinearSVC(featuresCol='features', labelCol='y')
clf_model = clf.fit(binary_df)
print(clf_model.intercept, clf_model.coefficients)
# Out:
# -1.0149273280183022 [0.000187712606328283,5.2578830515471725e-09,-7.9482226780511e-05,2.0908016936147597e-05,-0.0006652180215746111,3.426437268921949e-06,0.0003418718600226912]

# %%
import numpy as np
np.set_printoptions(precision=3, suppress=True)
binary_clf_model.coefficients
# Out:
# DenseVector([0.008, 0.0, -0.0017, 0.0036, -0.128, 0.0021, 0.0859])

# %% [markdown]
# # Neural networks

# %%
from pyspark.ml.classification import MultilayerPerceptronClassifier

#output_layer is set to 2 because of binary target
clf = MultilayerPerceptronClassifier(featuresCol='features', labelCol='y', layers=[4, 4, 2])
clf_model = clf.fit(binary_df)

# %% [markdown]
# # One vs rest classifier

# %%
target_variable_name = "education"
multiclass_df = data.select(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous', 'job', 'education'])
features_list = multiclass_df.columns
#features_list = char_vars #this option is used only for ChiSqselector
features_list.remove(target_variable_name)
# apply the function on our dataframe
multiclass_df = assemble_vectors(multiclass_df, features_list, target_variable_name)

# %%
from pyspark.ml.classification import RandomForestClassifier, OneVsRest
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# generate the train/test split.
(train, test) = multiclass_df.randomSplit([0.7, 0.3])
# instantiate the base classifier.
clf = RandomForestClassifier(featuresCol='features', labelCol='education')
# instantiate the One Vs Rest Classifier.
ovr = OneVsRest(classifier=clf, featuresCol='features', labelCol='education')
# train the multiclass model.
ovrModel = ovr.fit(train)
# score the model on test data.
predictions = ovrModel.transform(test)
# obtain evaluator.
evaluator = MulticlassClassificationEvaluator(metricName="accuracy", labelCol='education')
# compute the classification error on test data.
accuracy = evaluator.evaluate(predictions)
print("Test Error = %g" % (1.0 - accuracy))
# Out:
# Test Error = 0.332324

# %% [markdown]
# # Naive Bayes classifier

# %%
target_variable_name = "y"
nonneg_df = data.select(['age', 'day', 'duration', 'campaign', 'previous', 'y'])
#exclude target variable and select all other feature vectors
features_list = nonneg_df.columns
#features_list = char_vars #this option is used only for ChiSqselector
features_list.remove(target_variable_name)
# apply the function on our dataframe
nonneg_df = assemble_vectors(nonneg_df, features_list, target_variable_name)

# %%
from pyspark.ml.classification import NaiveBayes

#output_layer is set to 2 because of binary target
clf = NaiveBayes(featuresCol='features', labelCol='y')
clf_model = clf.fit(nonneg_df)
